# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.nn import Linear, Softmax, Sigmoid, Module
from scipy.optimize import minimize
from IPython.display import clear_output

# Creating/Formatting Data

import tensorflow as tf
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train[..., np.newaxis]/(255.0/np.pi), x_test[..., np.newaxis]/(255.0/np.pi)
print("Number of original training examples:", len(x_train))
print("Number of original test examples:", len(x_test))

# Filter Values
a = 0
b = 1
c = 2
d = 3
def filter_abcd(x, y):
    keep = (y == a) | (y == b) | (y == c) | (y == d)
    x, y = x[keep], y[keep]
    return x,y

# Filtering using previous method.
x_train, y_train = filter_abcd(x_train, y_train)
x_test, y_test = filter_abcd(x_test, y_test)

print("Number of filtered training examples:", len(x_train))
print("Number of filtered test examples:", len(x_test))

# Displaying Sample Image
img = 13
print(y_train[img])
plt.imshow(x_train[img, :, :, 0])
plt.colorbar()

# Resizing (Quantum Computing Simulation Limit)
x_train_small = tf.image.resize(x_train, (4,4), method = 'area').numpy()
x_test_small = tf.image.resize(x_test, (4,4), method = 'area').numpy()

# Displaying Image Sample After Resizing
img = 13
print(y_train[img])
plt.imshow(x_train_small[img,:,:,0], vmin=0, vmax=np.pi)
plt.colorbar()

# Formatting Helper Methods
def format_data(a,b):
    x_reshaped = []
    x1_reshaped = []

    for g in a:
        x_reshaped.append(g.reshape(1,16))

    for g in b:
        x1_reshaped.append(g.reshape(1,16))

    final_x = []
    final_x1 = []

    for entry in x_reshaped:
        final_x.append(entry[0])

    for entry in x1_reshaped:
        final_x1.append(entry[0])
    return final_x, final_x1

def format_labels(y):
    y_temp = []
    for entry in y:
        if entry == a:
            y_temp.append(0)
        elif entry == b:
            y_temp.append(1)
        elif entry == c:
            y_temp.append(2)
        elif entry == d:
            y_temp.append(3)
    return y_temp

x,x1 = format_data(x_train_small, x_test_small)

# Easier to work with names
y = y_train
y1 = y_test

# Setting labels to 0,1,2,3 for easy reference later
y = format_labels(y)
y1 = format_labels(y1)

# Converting to nparray
x = np.asarray(x)
y = np.asarray(y)
x1 = np.asarray(x1)
y1 = np.asarray(y1)

# Limiting training dataset to lower training time.
x = x[0:128]
y = y[0:128]
x1 = x1[0:128]
y1 = y1[0:128]
print(x)
print(y)

# Additional Helper Functions
def count(y):
    counta = 0
    countb = 0
    countc = 0
    countd = 0
    for i in range(len(y)):
        if y[i] == 0:
            counta+=1
        elif y[i] == 1:
            countb+=1
        elif y[i] == 2:
            countc+=1
        elif y[i] == 3:
            countd+=1
    return(counta, countb, countc, countd)

def balance_lists(x, y, max_count):
    """Balances two lists x and y based on the values in y (0 or 1)."""
    
    x_balanced = []
    y_balanced = []
    count0 = 0
    count1 = 0
    count2 = 0
    count3 = 0

    for i in range(len(y)):
        if y[i] == 0:
            if count0 < max_count:
                x_balanced.append(x[i])
                y_balanced.append(y[i])
                count0 += 1
        elif y[i] == 1:
            if count1 < max_count:
                x_balanced.append(x[i])
                y_balanced.append(y[i])
                count1 += 1
        elif y[i] == 2:
            if count2 < max_count:
                x_balanced.append(x[i])
                y_balanced.append(y[i])
                count2 += 1
        elif y[i] == 3:
            if count3 < max_count:
                x_balanced.append(x[i])
                y_balanced.append(y[i])
                count3 += 1
    return x_balanced, y_balanced

def shuffle(arr1, arr2):
    assert len(arr1) == len(arr2)
    p = np.random.permutation(len(arr1))
    return arr1[p], arr2[p]

# Further Data Cleaning Using Helper Functions
nums = count(y)
print("original:", nums)
max_count = min(nums)
print("max_count =", max_count)
x,y = balance_lists(x, y, max_count)

print("balanced:", count(y))

# Converting to nparray
x = np.asarray(x)
y = np.asarray(y)
x1 = np.asarray(x1)
y1 = np.asarray(y1)
objective_func_vals = []

x,y = shuffle(x,y)
print("shuffled:", count(y))

print("final:", x)
print(y)

# Tensor for Pytorch
X = torch.tensor(x, dtype=torch.float32).to("cuda").reshape(-1, 1, 4, 4)
Y = torch.tensor(y, dtype=torch.long).to("cuda")
X1 = torch.tensor(x1, dtype=torch.float32).to("cuda").reshape(-1, 1, 4, 4)
Y1 = torch.tensor(y1, dtype=torch.long).to("cuda")

# One-Hot Encoding for Final Processing
num_classes = 4
Y = (torch.nn.functional.one_hot(Y, num_classes=num_classes).float())
Y1 = (torch.nn.functional.one_hot(Y1, num_classes=num_classes).float())

print(X.shape,Y.shape,X1.shape,Y1.shape)

# Training

import torch
import torch.nn as nn
import torch.nn.functional as F

# Simplified CNN Model
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=4):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=4, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(4 * 2 * 2, num_classes)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = x.view(-1, 4 * 2 * 2)
        x = self.fc1(x)
        x = self.softmax(x)
        return x

# Create an instance of the model
model = SimpleCNN().to("cuda")

# Loss Function and Optimizer
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Accuracy Function
def accuracy(output, Y):
    preds = torch.argmax(output, dim=1)
    true = torch.argmax(Y, dim=1)
    correct = (preds == true).sum().item()
    return (correct / Y.size(0)) * 100

# Training Loop
def train(model, X, Y, optimizer, loss_function, epochs=100, batch_size=8):
    model.train()
    loss_list = []
    acc_list = []

    for epoch in range(epochs):
        for i in range(0, X.size(0), batch_size):
            X_batch = X[i:i + batch_size]
            Y_batch = Y[i:i + batch_size]

            # Forward pass
            output = model(X_batch)
            loss = loss_function(output, Y_batch)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # Calculate loss and accuracy for the entire epoch (optional, for monitoring)
        with torch.no_grad():
            output = model(X)
            epoch_loss = loss_function(output, Y).item()
            epoch_acc = accuracy(output, Y)
            loss_list.append(epoch_loss)
            acc_list.append(epoch_acc)
            print(f"Epoch: {epoch+1}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.2f}%")
    return loss_list, acc_list

# Train the Model
loss_list, acc_list = train(model, X, Y, optimizer, loss_function, epochs=1000)

# Plot Loss and Accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(loss_list)
plt.title("Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.subplot(1, 2, 2)
plt.plot(acc_list)
plt.title("Accuracy over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")

plt.tight_layout()
plt.show()

# Evaluate on Test Data
model.eval()
with torch.no_grad():
    output0 = model(X)
    output1 = model(X1)
    test_acc = accuracy(output1, Y1)
    print(f"Test Accuracy: {test_acc:.2f}%")

# Save the Model
torch.save(model.state_dict(), "cnn_model128.pth")
# Out:
# Number of original training examples: 60000
# Number of original test examples: 10000
# Number of filtered training examples: 24754
# Number of filtered test examples: 4157
# 2
# 2
# [[0.         0.01357711 0.87094647 ... 1.1276546  0.18178242 0.        ]
#  [0.         0.         0.37110767 ... 0.80205524 0.         0.        ]
#  [0.         0.00829712 0.38418198 ... 0.34772485 0.         0.        ]
#  ...
#  [0.         0.         0.28813645 ... 0.26173654 0.05355416 0.        ]
#  [0.         0.58532435 1.391151   ... 0.67382693 0.33037636 0.00276571]
#  [0.         0.35275346 0.81739247 ... 1.18674    0.4807303  0.        ]]
# [0 1 2 1 3 1 3 3 1 2 0 1 1 2 3 2 3 0 0 1 3 3 3 0 0 1 0 1 0 0 1 1 3 0 2 1 1
#  0 2 3 0 0 3 1 1 1 1 3 0 2 3 1 1 0 2 0 0 2 0 2 1 1 3 1 3 3 2 3 1 0 3 2 2 0
#  2 1 1 2 3 2 3 1 2 2 2 0 3 2 1 1 3 1 0 3 1 0 0 1 2 3 0 2 1 3 0 1 0 2 0 3 3
#  0 1 0 3 1 2 2 3 3 0 2 2 1 1 1 2 3]
# original: (31, 38, 28, 31)
# max_count = 28
# balanced: (28, 28, 28, 28)
# shuffled: (28, 28, 28, 28)
# final: [[0.         0.         0.31403354 ... 0.11012546 0.22025092 0.        ]
#  [0.         0.5073817  0.31227353 ... 1.0137576  1.0680661  0.12244541]
#  [0.         0.         0.73819256 ... 1.0107404  0.31604496 0.        ]
#  ...
#  [0.         0.24187371 0.35878772 ... 0.2562051  0.32559922 0.        ]
#  [0.         0.         0.         ... 0.25947368 0.03444563 0.        ]
#  [0.         0.02363423 0.33716494 ... 1.20434    0.4115876  0.        ]]
# [1 0 0 0 2 2 2 1 0 2 3 3 0 3 3 2 0 2 0 3 1 2 0 2 0 0 0 1 1 1 1 3 2 1 3 3 1
#  3 1 3 0 1 3 0 0 3 1 0 0 2 2 1 1 3 2 1 3 2 3 3 1 0 2 0 2 2 3 3 2 3 1 1 0 2
#  1 0 3 3 1 0 0 2 2 0 1 2 2 2 2 3 2 0 0 3 3 1 1 1 0 3 0 1 1 3 1 1 3 2 2 0 2
#  3]
# torch.Size([112, 1, 4, 4]) torch.Size([112, 4]) torch.Size([128, 1, 4, 4]) torch.Size([128, 4])
# Epoch: 1, Loss: 1.3806, Accuracy: 35.71%
# Epoch: 2, Loss: 1.3781, Accuracy: 41.96%
# Epoch: 3, Loss: 1.3759, Accuracy: 41.07%
# Epoch: 4, Loss: 1.3738, Accuracy: 38.39%
# Epoch: 5, Loss: 1.3716, Accuracy: 39.29%
# Epoch: 6, Loss: 1.3694, Accuracy: 39.29%
# Epoch: 7, Loss: 1.3671, Accuracy: 38.39%
# Epoch: 8, Loss: 1.3647, Accuracy: 39.29%
# Epoch: 9, Loss: 1.3623, Accuracy: 40.18%
# Epoch: 10, Loss: 1.3596, Accuracy: 41.07%
# Epoch: 11, Loss: 1.3567, Accuracy: 42.86%
# Epoch: 12, Loss: 1.3534, Accuracy: 45.54%
# Epoch: 13, Loss: 1.3499, Accuracy: 47.32%
# Epoch: 14, Loss: 1.3463, Accuracy: 48.21%
# Epoch: 15, Loss: 1.3427, Accuracy: 48.21%
# Epoch: 16, Loss: 1.3389, Accuracy: 49.11%
# Epoch: 17, Loss: 1.3350, Accuracy: 51.79%
# Epoch: 18, Loss: 1.3310, Accuracy: 54.46%
# Epoch: 19, Loss: 1.3268, Accuracy: 57.14%
# Epoch: 20, Loss: 1.3225, Accuracy: 59.82%
# Epoch: 21, Loss: 1.3180, Accuracy: 63.39%
# Epoch: 22, Loss: 1.3134, Accuracy: 66.07%
# Epoch: 23, Loss: 1.3086, Accuracy: 66.96%
# Epoch: 24, Loss: 1.3036, Accuracy: 66.96%
# Epoch: 25, Loss: 1.2984, Accuracy: 67.86%
# Epoch: 26, Loss: 1.2930, Accuracy: 72.32%
# Epoch: 27, Loss: 1.2875, Accuracy: 73.21%
# Epoch: 28, Loss: 1.2818, Accuracy: 73.21%
# Epoch: 29, Loss: 1.2759, Accuracy: 77.68%
# Epoch: 30, Loss: 1.2699, Accuracy: 78.57%
# Epoch: 31, Loss: 1.2637, Accuracy: 80.36%
# Epoch: 32, Loss: 1.2572, Accuracy: 81.25%
# Epoch: 33, Loss: 1.2505, Accuracy: 83.04%
# Epoch: 34, Loss: 1.2438, Accuracy: 83.93%
# Epoch: 35, Loss: 1.2368, Accuracy: 83.93%
# Epoch: 36, Loss: 1.2297, Accuracy: 83.93%
# Epoch: 37, Loss: 1.2225, Accuracy: 83.04%
# Epoch: 38, Loss: 1.2152, Accuracy: 83.93%
# Epoch: 39, Loss: 1.2076, Accuracy: 83.93%
# Epoch: 40, Loss: 1.1999, Accuracy: 84.82%
# Epoch: 41, Loss: 1.1916, Accuracy: 84.82%
# Epoch: 42, Loss: 1.1831, Accuracy: 84.82%
# Epoch: 43, Loss: 1.1747, Accuracy: 84.82%
# Epoch: 44, Loss: 1.1667, Accuracy: 85.71%
# Epoch: 45, Loss: 1.1588, Accuracy: 85.71%
# Epoch: 46, Loss: 1.1511, Accuracy: 86.61%
# Epoch: 47, Loss: 1.1436, Accuracy: 86.61%
# Epoch: 48, Loss: 1.1362, Accuracy: 86.61%
# Epoch: 49, Loss: 1.1291, Accuracy: 85.71%
# Epoch: 50, Loss: 1.1221, Accuracy: 84.82%
# Epoch: 51, Loss: 1.1152, Accuracy: 84.82%
# Epoch: 52, Loss: 1.1086, Accuracy: 84.82%
# Epoch: 53, Loss: 1.1021, Accuracy: 83.93%
# Epoch: 54, Loss: 1.0958, Accuracy: 83.93%
# Epoch: 55, Loss: 1.0897, Accuracy: 83.93%
# Epoch: 56, Loss: 1.0838, Accuracy: 83.93%
# Epoch: 57, Loss: 1.0780, Accuracy: 83.93%
# Epoch: 58, Loss: 1.0725, Accuracy: 84.82%
# Epoch: 59, Loss: 1.0671, Accuracy: 84.82%
# Epoch: 60, Loss: 1.0619, Accuracy: 84.82%
# Epoch: 61, Loss: 1.0569, Accuracy: 84.82%
# Epoch: 62, Loss: 1.0520, Accuracy: 84.82%
# Epoch: 63, Loss: 1.0473, Accuracy: 84.82%
# Epoch: 64, Loss: 1.0427, Accuracy: 85.71%
# Epoch: 65, Loss: 1.0383, Accuracy: 85.71%
# Epoch: 66, Loss: 1.0340, Accuracy: 85.71%
# Epoch: 67, Loss: 1.0298, Accuracy: 85.71%
# Epoch: 68, Loss: 1.0258, Accuracy: 85.71%
# Epoch: 69, Loss: 1.0219, Accuracy: 85.71%
# Epoch: 70, Loss: 1.0181, Accuracy: 86.61%
# Epoch: 71, Loss: 1.0145, Accuracy: 86.61%
# Epoch: 72, Loss: 1.0110, Accuracy: 86.61%
# Epoch: 73, Loss: 1.0076, Accuracy: 86.61%
# Epoch: 74, Loss: 1.0043, Accuracy: 86.61%
# Epoch: 75, Loss: 1.0012, Accuracy: 86.61%
# Epoch: 76, Loss: 0.9981, Accuracy: 86.61%
# Epoch: 77, Loss: 0.9952, Accuracy: 86.61%
# Epoch: 78, Loss: 0.9923, Accuracy: 86.61%
# Epoch: 79, Loss: 0.9896, Accuracy: 86.61%
# Epoch: 80, Loss: 0.9869, Accuracy: 86.61%
# Epoch: 81, Loss: 0.9843, Accuracy: 86.61%
# Epoch: 82, Loss: 0.9818, Accuracy: 86.61%
# Epoch: 83, Loss: 0.9794, Accuracy: 88.39%
# Epoch: 84, Loss: 0.9770, Accuracy: 88.39%
# Epoch: 85, Loss: 0.9747, Accuracy: 88.39%
# Epoch: 86, Loss: 0.9725, Accuracy: 88.39%
# Epoch: 87, Loss: 0.9704, Accuracy: 88.39%
# Epoch: 88, Loss: 0.9683, Accuracy: 88.39%
# Epoch: 89, Loss: 0.9663, Accuracy: 88.39%
# Epoch: 90, Loss: 0.9643, Accuracy: 88.39%
# Epoch: 91, Loss: 0.9624, Accuracy: 88.39%
# Epoch: 92, Loss: 0.9605, Accuracy: 88.39%
# Epoch: 93, Loss: 0.9587, Accuracy: 88.39%
# Epoch: 94, Loss: 0.9569, Accuracy: 88.39%
# Epoch: 95, Loss: 0.9552, Accuracy: 88.39%
# Epoch: 96, Loss: 0.9535, Accuracy: 88.39%
# Epoch: 97, Loss: 0.9519, Accuracy: 88.39%
# Epoch: 98, Loss: 0.9502, Accuracy: 88.39%
# Epoch: 99, Loss: 0.9487, Accuracy: 88.39%
# Epoch: 100, Loss: 0.9471, Accuracy: 88.39%
# Epoch: 101, Loss: 0.9456, Accuracy: 88.39%
# Epoch: 102, Loss: 0.9442, Accuracy: 88.39%
# Epoch: 103, Loss: 0.9427, Accuracy: 88.39%
# Epoch: 104, Loss: 0.9413, Accuracy: 88.39%
# Epoch: 105, Loss: 0.9399, Accuracy: 88.39%
# Epoch: 106, Loss: 0.9386, Accuracy: 88.39%
# Epoch: 107, Loss: 0.9373, Accuracy: 88.39%
# Epoch: 108, Loss: 0.9360, Accuracy: 88.39%
# Epoch: 109, Loss: 0.9347, Accuracy: 88.39%
# Epoch: 110, Loss: 0.9335, Accuracy: 88.39%
# Epoch: 111, Loss: 0.9323, Accuracy: 88.39%
# Epoch: 112, Loss: 0.9312, Accuracy: 88.39%
# Epoch: 113, Loss: 0.9300, Accuracy: 88.39%
# Epoch: 114, Loss: 0.9289, Accuracy: 88.39%
# Epoch: 115, Loss: 0.9278, Accuracy: 88.39%
# Epoch: 116, Loss: 0.9267, Accuracy: 88.39%
# Epoch: 117, Loss: 0.9257, Accuracy: 88.39%
# Epoch: 118, Loss: 0.9247, Accuracy: 88.39%
# Epoch: 119, Loss: 0.9237, Accuracy: 88.39%
# Epoch: 120, Loss: 0.9227, Accuracy: 88.39%
# Epoch: 121, Loss: 0.9217, Accuracy: 88.39%
# Epoch: 122, Loss: 0.9208, Accuracy: 88.39%
# Epoch: 123, Loss: 0.9199, Accuracy: 88.39%
# Epoch: 124, Loss: 0.9189, Accuracy: 88.39%
# Epoch: 125, Loss: 0.9181, Accuracy: 88.39%
# Epoch: 126, Loss: 0.9172, Accuracy: 88.39%
# Epoch: 127, Loss: 0.9163, Accuracy: 88.39%
# Epoch: 128, Loss: 0.9155, Accuracy: 88.39%
# Epoch: 129, Loss: 0.9147, Accuracy: 88.39%
# Epoch: 130, Loss: 0.9139, Accuracy: 88.39%
# Epoch: 131, Loss: 0.9131, Accuracy: 88.39%
# Epoch: 132, Loss: 0.9123, Accuracy: 88.39%
# Epoch: 133, Loss: 0.9115, Accuracy: 88.39%
# Epoch: 134, Loss: 0.9107, Accuracy: 88.39%
# Epoch: 135, Loss: 0.9100, Accuracy: 88.39%
# Epoch: 136, Loss: 0.9092, Accuracy: 88.39%
# Epoch: 137, Loss: 0.9085, Accuracy: 88.39%
# Epoch: 138, Loss: 0.9078, Accuracy: 88.39%
# Epoch: 139, Loss: 0.9071, Accuracy: 88.39%
# Epoch: 140, Loss: 0.9063, Accuracy: 88.39%
# Epoch: 141, Loss: 0.9057, Accuracy: 88.39%
# Epoch: 142, Loss: 0.9050, Accuracy: 88.39%
# Epoch: 143, Loss: 0.9043, Accuracy: 88.39%
# Epoch: 144, Loss: 0.9036, Accuracy: 88.39%
# Epoch: 145, Loss: 0.9030, Accuracy: 88.39%
# Epoch: 146, Loss: 0.9023, Accuracy: 88.39%
# Epoch: 147, Loss: 0.9017, Accuracy: 88.39%
# Epoch: 148, Loss: 0.9011, Accuracy: 88.39%
# Epoch: 149, Loss: 0.9004, Accuracy: 88.39%
# Epoch: 150, Loss: 0.8998, Accuracy: 88.39%
# Epoch: 151, Loss: 0.8992, Accuracy: 88.39%
# Epoch: 152, Loss: 0.8986, Accuracy: 89.29%
# Epoch: 153, Loss: 0.8980, Accuracy: 89.29%
# Epoch: 154, Loss: 0.8974, Accuracy: 89.29%
# Epoch: 155, Loss: 0.8967, Accuracy: 89.29%
# Epoch: 156, Loss: 0.8961, Accuracy: 89.29%
# Epoch: 157, Loss: 0.8955, Accuracy: 89.29%
# Epoch: 158, Loss: 0.8949, Accuracy: 89.29%
# Epoch: 159, Loss: 0.8943, Accuracy: 89.29%
# Epoch: 160, Loss: 0.8937, Accuracy: 89.29%
# Epoch: 161, Loss: 0.8931, Accuracy: 89.29%
# Epoch: 162, Loss: 0.8925, Accuracy: 89.29%
# Epoch: 163, Loss: 0.8919, Accuracy: 88.39%
# Epoch: 164, Loss: 0.8913, Accuracy: 88.39%
# Epoch: 165, Loss: 0.8908, Accuracy: 88.39%
# Epoch: 166, Loss: 0.8902, Accuracy: 88.39%
# Epoch: 167, Loss: 0.8897, Accuracy: 88.39%
# Epoch: 168, Loss: 0.8891, Accuracy: 88.39%
# Epoch: 169, Loss: 0.8886, Accuracy: 88.39%
# Epoch: 170, Loss: 0.8881, Accuracy: 88.39%
# Epoch: 171, Loss: 0.8876, Accuracy: 88.39%
# Epoch: 172, Loss: 0.8870, Accuracy: 88.39%
# Epoch: 173, Loss: 0.8865, Accuracy: 88.39%
# Epoch: 174, Loss: 0.8859, Accuracy: 88.39%
# Epoch: 175, Loss: 0.8853, Accuracy: 88.39%
# Epoch: 176, Loss: 0.8846, Accuracy: 88.39%
# Epoch: 177, Loss: 0.8838, Accuracy: 88.39%
# Epoch: 178, Loss: 0.8831, Accuracy: 88.39%
# Epoch: 179, Loss: 0.8825, Accuracy: 89.29%
# Epoch: 180, Loss: 0.8818, Accuracy: 89.29%
# Epoch: 181, Loss: 0.8811, Accuracy: 89.29%
# Epoch: 182, Loss: 0.8804, Accuracy: 89.29%
# Epoch: 183, Loss: 0.8797, Accuracy: 90.18%
# Epoch: 184, Loss: 0.8790, Accuracy: 90.18%
# Epoch: 185, Loss: 0.8783, Accuracy: 90.18%
# Epoch: 186, Loss: 0.8776, Accuracy: 90.18%
# Epoch: 187, Loss: 0.8770, Accuracy: 90.18%
# Epoch: 188, Loss: 0.8763, Accuracy: 90.18%
# Epoch: 189, Loss: 0.8757, Accuracy: 90.18%
# Epoch: 190, Loss: 0.8750, Accuracy: 90.18%
# Epoch: 191, Loss: 0.8744, Accuracy: 91.07%
# Epoch: 192, Loss: 0.8738, Accuracy: 91.07%
# Epoch: 193, Loss: 0.8732, Accuracy: 91.07%
# Epoch: 194, Loss: 0.8726, Accuracy: 91.07%
# Epoch: 195, Loss: 0.8721, Accuracy: 91.07%
# Epoch: 196, Loss: 0.8716, Accuracy: 91.07%
# Epoch: 197, Loss: 0.8711, Accuracy: 91.07%
# Epoch: 198, Loss: 0.8706, Accuracy: 91.07%
# Epoch: 199, Loss: 0.8701, Accuracy: 91.07%
# Epoch: 200, Loss: 0.8696, Accuracy: 91.07%
# Epoch: 201, Loss: 0.8691, Accuracy: 91.07%
# Epoch: 202, Loss: 0.8686, Accuracy: 91.07%
# Epoch: 203, Loss: 0.8682, Accuracy: 91.07%
# Epoch: 204, Loss: 0.8677, Accuracy: 91.07%
# Epoch: 205, Loss: 0.8673, Accuracy: 91.07%
# Epoch: 206, Loss: 0.8668, Accuracy: 91.07%
# Epoch: 207, Loss: 0.8664, Accuracy: 91.07%
# Epoch: 208, Loss: 0.8660, Accuracy: 91.07%
# Epoch: 209, Loss: 0.8655, Accuracy: 91.07%
# Epoch: 210, Loss: 0.8651, Accuracy: 91.07%
# Epoch: 211, Loss: 0.8647, Accuracy: 91.07%
# Epoch: 212, Loss: 0.8643, Accuracy: 91.07%
# Epoch: 213, Loss: 0.8639, Accuracy: 91.07%
# Epoch: 214, Loss: 0.8635, Accuracy: 91.07%
# Epoch: 215, Loss: 0.8631, Accuracy: 91.07%
# Epoch: 216, Loss: 0.8627, Accuracy: 91.07%
# Epoch: 217, Loss: 0.8623, Accuracy: 91.07%
# Epoch: 218, Loss: 0.8619, Accuracy: 91.07%
# Epoch: 219, Loss: 0.8615, Accuracy: 91.07%
# Epoch: 220, Loss: 0.8611, Accuracy: 91.07%
# Epoch: 221, Loss: 0.8607, Accuracy: 91.07%
# Epoch: 222, Loss: 0.8603, Accuracy: 91.07%
# Epoch: 223, Loss: 0.8599, Accuracy: 91.07%
# Epoch: 224, Loss: 0.8596, Accuracy: 91.07%
# Epoch: 225, Loss: 0.8592, Accuracy: 91.07%
# Epoch: 226, Loss: 0.8588, Accuracy: 91.07%
# Epoch: 227, Loss: 0.8584, Accuracy: 91.07%
# Epoch: 228, Loss: 0.8581, Accuracy: 91.07%
# Epoch: 229, Loss: 0.8577, Accuracy: 91.07%
# Epoch: 230, Loss: 0.8573, Accuracy: 91.07%
# Epoch: 231, Loss: 0.8570, Accuracy: 91.07%
# Epoch: 232, Loss: 0.8566, Accuracy: 91.07%
# Epoch: 233, Loss: 0.8563, Accuracy: 91.07%
# Epoch: 234, Loss: 0.8560, Accuracy: 91.07%
# Epoch: 235, Loss: 0.8556, Accuracy: 91.07%
# Epoch: 236, Loss: 0.8553, Accuracy: 91.07%
# Epoch: 237, Loss: 0.8549, Accuracy: 91.07%
# Epoch: 238, Loss: 0.8546, Accuracy: 91.07%
# Epoch: 239, Loss: 0.8543, Accuracy: 91.07%
# Epoch: 240, Loss: 0.8540, Accuracy: 91.07%
# Epoch: 241, Loss: 0.8536, Accuracy: 91.07%
# Epoch: 242, Loss: 0.8533, Accuracy: 91.07%
# Epoch: 243, Loss: 0.8530, Accuracy: 91.07%
# Epoch: 244, Loss: 0.8527, Accuracy: 91.07%
# Epoch: 245, Loss: 0.8524, Accuracy: 91.96%
# Epoch: 246, Loss: 0.8521, Accuracy: 91.96%
# Epoch: 247, Loss: 0.8517, Accuracy: 91.96%
# Epoch: 248, Loss: 0.8514, Accuracy: 91.96%
# Epoch: 249, Loss: 0.8511, Accuracy: 91.96%
# Epoch: 250, Loss: 0.8508, Accuracy: 91.96%
# Epoch: 251, Loss: 0.8505, Accuracy: 91.96%
# Epoch: 252, Loss: 0.8502, Accuracy: 91.96%
# Epoch: 253, Loss: 0.8499, Accuracy: 91.96%
# Epoch: 254, Loss: 0.8496, Accuracy: 91.96%
# Epoch: 255, Loss: 0.8493, Accuracy: 91.96%
# Epoch: 256, Loss: 0.8490, Accuracy: 91.96%
# Epoch: 257, Loss: 0.8487, Accuracy: 91.96%
# Epoch: 258, Loss: 0.8485, Accuracy: 91.96%
# Epoch: 259, Loss: 0.8482, Accuracy: 91.96%
# Epoch: 260, Loss: 0.8479, Accuracy: 91.96%
# Epoch: 261, Loss: 0.8476, Accuracy: 91.96%
# Epoch: 262, Loss: 0.8473, Accuracy: 91.96%
# Epoch: 263, Loss: 0.8470, Accuracy: 91.96%
# Epoch: 264, Loss: 0.8468, Accuracy: 91.96%
# Epoch: 265, Loss: 0.8465, Accuracy: 91.96%
# Epoch: 266, Loss: 0.8462, Accuracy: 91.96%
# Epoch: 267, Loss: 0.8459, Accuracy: 91.96%
# Epoch: 268, Loss: 0.8457, Accuracy: 92.86%
# Epoch: 269, Loss: 0.8454, Accuracy: 92.86%
# Epoch: 270, Loss: 0.8451, Accuracy: 92.86%
# Epoch: 271, Loss: 0.8449, Accuracy: 93.75%
# Epoch: 272, Loss: 0.8446, Accuracy: 93.75%
# Epoch: 273, Loss: 0.8443, Accuracy: 93.75%
# Epoch: 274, Loss: 0.8441, Accuracy: 93.75%
# Epoch: 275, Loss: 0.8438, Accuracy: 93.75%
# Epoch: 276, Loss: 0.8435, Accuracy: 93.75%
# Epoch: 277, Loss: 0.8433, Accuracy: 93.75%
# Epoch: 278, Loss: 0.8430, Accuracy: 93.75%
# Epoch: 279, Loss: 0.8427, Accuracy: 93.75%
# Epoch: 280, Loss: 0.8425, Accuracy: 93.75%
# Epoch: 281, Loss: 0.8422, Accuracy: 93.75%
# Epoch: 282, Loss: 0.8420, Accuracy: 93.75%
# Epoch: 283, Loss: 0.8417, Accuracy: 93.75%
# Epoch: 284, Loss: 0.8415, Accuracy: 93.75%
# Epoch: 285, Loss: 0.8412, Accuracy: 93.75%
# Epoch: 286, Loss: 0.8410, Accuracy: 93.75%
# Epoch: 287, Loss: 0.8407, Accuracy: 93.75%
# Epoch: 288, Loss: 0.8405, Accuracy: 93.75%
# Epoch: 289, Loss: 0.8402, Accuracy: 93.75%
# Epoch: 290, Loss: 0.8400, Accuracy: 93.75%
# Epoch: 291, Loss: 0.8397, Accuracy: 93.75%
# Epoch: 292, Loss: 0.8395, Accuracy: 93.75%
# Epoch: 293, Loss: 0.8393, Accuracy: 93.75%
# Epoch: 294, Loss: 0.8390, Accuracy: 93.75%
# Epoch: 295, Loss: 0.8388, Accuracy: 93.75%
# Epoch: 296, Loss: 0.8385, Accuracy: 93.75%
# Epoch: 297, Loss: 0.8383, Accuracy: 93.75%
# Epoch: 298, Loss: 0.8381, Accuracy: 93.75%
# Epoch: 299, Loss: 0.8379, Accuracy: 93.75%
# Epoch: 300, Loss: 0.8376, Accuracy: 93.75%
# Epoch: 301, Loss: 0.8374, Accuracy: 93.75%
# Epoch: 302, Loss: 0.8372, Accuracy: 93.75%
# Epoch: 303, Loss: 0.8369, Accuracy: 93.75%
# Epoch: 304, Loss: 0.8367, Accuracy: 93.75%
# Epoch: 305, Loss: 0.8365, Accuracy: 93.75%
# Epoch: 306, Loss: 0.8363, Accuracy: 93.75%
# Epoch: 307, Loss: 0.8361, Accuracy: 93.75%
# Epoch: 308, Loss: 0.8358, Accuracy: 93.75%
# Epoch: 309, Loss: 0.8356, Accuracy: 93.75%
# Epoch: 310, Loss: 0.8354, Accuracy: 93.75%
# Epoch: 311, Loss: 0.8352, Accuracy: 93.75%
# Epoch: 312, Loss: 0.8350, Accuracy: 93.75%
# Epoch: 313, Loss: 0.8348, Accuracy: 93.75%
# Epoch: 314, Loss: 0.8346, Accuracy: 93.75%
# Epoch: 315, Loss: 0.8344, Accuracy: 93.75%
# Epoch: 316, Loss: 0.8342, Accuracy: 93.75%
# Epoch: 317, Loss: 0.8340, Accuracy: 93.75%
# Epoch: 318, Loss: 0.8338, Accuracy: 93.75%
# Epoch: 319, Loss: 0.8335, Accuracy: 93.75%
# Epoch: 320, Loss: 0.8333, Accuracy: 93.75%
# Epoch: 321, Loss: 0.8332, Accuracy: 93.75%
# Epoch: 322, Loss: 0.8330, Accuracy: 93.75%
# Epoch: 323, Loss: 0.8328, Accuracy: 93.75%
# Epoch: 324, Loss: 0.8326, Accuracy: 93.75%
# Epoch: 325, Loss: 0.8324, Accuracy: 93.75%
# Epoch: 326, Loss: 0.8322, Accuracy: 93.75%
# Epoch: 327, Loss: 0.8320, Accuracy: 93.75%
# Epoch: 328, Loss: 0.8318, Accuracy: 93.75%
# Epoch: 329, Loss: 0.8316, Accuracy: 93.75%
# Epoch: 330, Loss: 0.8314, Accuracy: 93.75%
# Epoch: 331, Loss: 0.8312, Accuracy: 93.75%
# Epoch: 332, Loss: 0.8310, Accuracy: 93.75%
# Epoch: 333, Loss: 0.8308, Accuracy: 94.64%
# Epoch: 334, Loss: 0.8306, Accuracy: 94.64%
# Epoch: 335, Loss: 0.8304, Accuracy: 94.64%
# Epoch: 336, Loss: 0.8303, Accuracy: 94.64%
# Epoch: 337, Loss: 0.8301, Accuracy: 94.64%
# Epoch: 338, Loss: 0.8299, Accuracy: 94.64%
# Epoch: 339, Loss: 0.8297, Accuracy: 94.64%
# Epoch: 340, Loss: 0.8295, Accuracy: 94.64%
# Epoch: 341, Loss: 0.8294, Accuracy: 94.64%
# Epoch: 342, Loss: 0.8292, Accuracy: 94.64%
# Epoch: 343, Loss: 0.8290, Accuracy: 94.64%
# Epoch: 344, Loss: 0.8288, Accuracy: 94.64%
# Epoch: 345, Loss: 0.8286, Accuracy: 94.64%
# Epoch: 346, Loss: 0.8285, Accuracy: 94.64%
# Epoch: 347, Loss: 0.8283, Accuracy: 94.64%
# Epoch: 348, Loss: 0.8281, Accuracy: 94.64%
# Epoch: 349, Loss: 0.8279, Accuracy: 94.64%
# Epoch: 350, Loss: 0.8278, Accuracy: 94.64%
# Epoch: 351, Loss: 0.8276, Accuracy: 94.64%
# Epoch: 352, Loss: 0.8274, Accuracy: 94.64%
# Epoch: 353, Loss: 0.8273, Accuracy: 94.64%
# Epoch: 354, Loss: 0.8271, Accuracy: 94.64%
# Epoch: 355, Loss: 0.8269, Accuracy: 94.64%
# Epoch: 356, Loss: 0.8268, Accuracy: 94.64%
# Epoch: 357, Loss: 0.8266, Accuracy: 94.64%
# Epoch: 358, Loss: 0.8264, Accuracy: 94.64%
# Epoch: 359, Loss: 0.8263, Accuracy: 94.64%
# Epoch: 360, Loss: 0.8261, Accuracy: 94.64%
# Epoch: 361, Loss: 0.8259, Accuracy: 94.64%
# Epoch: 362, Loss: 0.8258, Accuracy: 94.64%
# Epoch: 363, Loss: 0.8256, Accuracy: 94.64%
# Epoch: 364, Loss: 0.8255, Accuracy: 94.64%
# Epoch: 365, Loss: 0.8253, Accuracy: 94.64%
# Epoch: 366, Loss: 0.8251, Accuracy: 94.64%
# Epoch: 367, Loss: 0.8250, Accuracy: 94.64%
# Epoch: 368, Loss: 0.8248, Accuracy: 94.64%
# Epoch: 369, Loss: 0.8247, Accuracy: 94.64%
# Epoch: 370, Loss: 0.8245, Accuracy: 94.64%
# Epoch: 371, Loss: 0.8244, Accuracy: 94.64%
# Epoch: 372, Loss: 0.8242, Accuracy: 94.64%
# Epoch: 373, Loss: 0.8240, Accuracy: 94.64%
# Epoch: 374, Loss: 0.8239, Accuracy: 94.64%
# Epoch: 375, Loss: 0.8237, Accuracy: 94.64%
# Epoch: 376, Loss: 0.8236, Accuracy: 94.64%
# Epoch: 377, Loss: 0.8234, Accuracy: 94.64%
# Epoch: 378, Loss: 0.8233, Accuracy: 94.64%
# Epoch: 379, Loss: 0.8231, Accuracy: 94.64%
# Epoch: 380, Loss: 0.8229, Accuracy: 94.64%
# Epoch: 381, Loss: 0.8228, Accuracy: 94.64%
# Epoch: 382, Loss: 0.8226, Accuracy: 94.64%
# Epoch: 383, Loss: 0.8225, Accuracy: 94.64%
# Epoch: 384, Loss: 0.8223, Accuracy: 94.64%
# Epoch: 385, Loss: 0.8222, Accuracy: 94.64%
# Epoch: 386, Loss: 0.8220, Accuracy: 94.64%
# Epoch: 387, Loss: 0.8219, Accuracy: 94.64%
# Epoch: 388, Loss: 0.8217, Accuracy: 94.64%
# Epoch: 389, Loss: 0.8216, Accuracy: 94.64%
# Epoch: 390, Loss: 0.8214, Accuracy: 94.64%
# Epoch: 391, Loss: 0.8213, Accuracy: 94.64%
# Epoch: 392, Loss: 0.8211, Accuracy: 94.64%
# Epoch: 393, Loss: 0.8210, Accuracy: 94.64%
# Epoch: 394, Loss: 0.8208, Accuracy: 94.64%
# Epoch: 395, Loss: 0.8207, Accuracy: 94.64%
# Epoch: 396, Loss: 0.8206, Accuracy: 94.64%
# Epoch: 397, Loss: 0.8204, Accuracy: 94.64%
# Epoch: 398, Loss: 0.8203, Accuracy: 94.64%
# Epoch: 399, Loss: 0.8201, Accuracy: 94.64%
# Epoch: 400, Loss: 0.8200, Accuracy: 94.64%
# Epoch: 401, Loss: 0.8198, Accuracy: 94.64%
# Epoch: 402, Loss: 0.8197, Accuracy: 94.64%
# Epoch: 403, Loss: 0.8195, Accuracy: 94.64%
# Epoch: 404, Loss: 0.8194, Accuracy: 94.64%
# Epoch: 405, Loss: 0.8193, Accuracy: 94.64%
# Epoch: 406, Loss: 0.8191, Accuracy: 94.64%
# Epoch: 407, Loss: 0.8190, Accuracy: 94.64%
# Epoch: 408, Loss: 0.8188, Accuracy: 94.64%
# Epoch: 409, Loss: 0.8187, Accuracy: 94.64%
# Epoch: 410, Loss: 0.8186, Accuracy: 94.64%
# Epoch: 411, Loss: 0.8184, Accuracy: 94.64%
# Epoch: 412, Loss: 0.8183, Accuracy: 94.64%
# Epoch: 413, Loss: 0.8181, Accuracy: 94.64%
# Epoch: 414, Loss: 0.8180, Accuracy: 94.64%
# Epoch: 415, Loss: 0.8179, Accuracy: 94.64%
# Epoch: 416, Loss: 0.8177, Accuracy: 94.64%
# Epoch: 417, Loss: 0.8176, Accuracy: 94.64%
# Epoch: 418, Loss: 0.8175, Accuracy: 94.64%
# Epoch: 419, Loss: 0.8173, Accuracy: 94.64%
# Epoch: 420, Loss: 0.8172, Accuracy: 94.64%
# Epoch: 421, Loss: 0.8171, Accuracy: 94.64%
# Epoch: 422, Loss: 0.8169, Accuracy: 94.64%
# Epoch: 423, Loss: 0.8168, Accuracy: 94.64%
# Epoch: 424, Loss: 0.8167, Accuracy: 94.64%
# Epoch: 425, Loss: 0.8165, Accuracy: 94.64%
# Epoch: 426, Loss: 0.8164, Accuracy: 94.64%
# Epoch: 427, Loss: 0.8163, Accuracy: 94.64%
# Epoch: 428, Loss: 0.8161, Accuracy: 94.64%
# Epoch: 429, Loss: 0.8160, Accuracy: 94.64%
# Epoch: 430, Loss: 0.8159, Accuracy: 94.64%
# Epoch: 431, Loss: 0.8157, Accuracy: 95.54%
# Epoch: 432, Loss: 0.8156, Accuracy: 95.54%
# Epoch: 433, Loss: 0.8155, Accuracy: 95.54%
# Epoch: 434, Loss: 0.8154, Accuracy: 95.54%
# Epoch: 435, Loss: 0.8152, Accuracy: 95.54%
# Epoch: 436, Loss: 0.8151, Accuracy: 95.54%
# Epoch: 437, Loss: 0.8150, Accuracy: 95.54%
# Epoch: 438, Loss: 0.8148, Accuracy: 95.54%
# Epoch: 439, Loss: 0.8147, Accuracy: 95.54%
# Epoch: 440, Loss: 0.8146, Accuracy: 95.54%
# Epoch: 441, Loss: 0.8145, Accuracy: 95.54%
# Epoch: 442, Loss: 0.8143, Accuracy: 95.54%
# Epoch: 443, Loss: 0.8142, Accuracy: 95.54%
# Epoch: 444, Loss: 0.8141, Accuracy: 95.54%
# Epoch: 445, Loss: 0.8139, Accuracy: 95.54%
# Epoch: 446, Loss: 0.8138, Accuracy: 95.54%
# Epoch: 447, Loss: 0.8137, Accuracy: 95.54%
# Epoch: 448, Loss: 0.8136, Accuracy: 95.54%
# Epoch: 449, Loss: 0.8135, Accuracy: 95.54%
# Epoch: 450, Loss: 0.8133, Accuracy: 95.54%
# Epoch: 451, Loss: 0.8132, Accuracy: 95.54%
# Epoch: 452, Loss: 0.8131, Accuracy: 95.54%
# Epoch: 453, Loss: 0.8130, Accuracy: 95.54%
# Epoch: 454, Loss: 0.8128, Accuracy: 95.54%
# Epoch: 455, Loss: 0.8127, Accuracy: 95.54%
# Epoch: 456, Loss: 0.8126, Accuracy: 95.54%
# Epoch: 457, Loss: 0.8125, Accuracy: 95.54%
# Epoch: 458, Loss: 0.8123, Accuracy: 95.54%
# Epoch: 459, Loss: 0.8122, Accuracy: 95.54%
# Epoch: 460, Loss: 0.8121, Accuracy: 95.54%
# Epoch: 461, Loss: 0.8120, Accuracy: 95.54%
# Epoch: 462, Loss: 0.8119, Accuracy: 95.54%
# Epoch: 463, Loss: 0.8117, Accuracy: 95.54%
# Epoch: 464, Loss: 0.8116, Accuracy: 95.54%
# Epoch: 465, Loss: 0.8115, Accuracy: 95.54%
# Epoch: 466, Loss: 0.8114, Accuracy: 95.54%
# Epoch: 467, Loss: 0.8113, Accuracy: 95.54%
# Epoch: 468, Loss: 0.8112, Accuracy: 95.54%
# Epoch: 469, Loss: 0.8110, Accuracy: 95.54%
# Epoch: 470, Loss: 0.8109, Accuracy: 95.54%
# Epoch: 471, Loss: 0.8108, Accuracy: 95.54%
# Epoch: 472, Loss: 0.8107, Accuracy: 95.54%
# Epoch: 473, Loss: 0.8106, Accuracy: 95.54%
# Epoch: 474, Loss: 0.8105, Accuracy: 95.54%
# Epoch: 475, Loss: 0.8104, Accuracy: 95.54%
# Epoch: 476, Loss: 0.8102, Accuracy: 95.54%
# Epoch: 477, Loss: 0.8101, Accuracy: 95.54%
# Epoch: 478, Loss: 0.8100, Accuracy: 95.54%
# Epoch: 479, Loss: 0.8099, Accuracy: 95.54%
# Epoch: 480, Loss: 0.8098, Accuracy: 95.54%
# Epoch: 481, Loss: 0.8097, Accuracy: 95.54%
# Epoch: 482, Loss: 0.8096, Accuracy: 95.54%
# Epoch: 483, Loss: 0.8095, Accuracy: 95.54%
# Epoch: 484, Loss: 0.8094, Accuracy: 95.54%
# Epoch: 485, Loss: 0.8093, Accuracy: 95.54%
# Epoch: 486, Loss: 0.8092, Accuracy: 95.54%
# Epoch: 487, Loss: 0.8091, Accuracy: 95.54%
# Epoch: 488, Loss: 0.8090, Accuracy: 95.54%
# Epoch: 489, Loss: 0.8089, Accuracy: 95.54%
# Epoch: 490, Loss: 0.8087, Accuracy: 95.54%
# Epoch: 491, Loss: 0.8086, Accuracy: 95.54%
# Epoch: 492, Loss: 0.8085, Accuracy: 95.54%
# Epoch: 493, Loss: 0.8084, Accuracy: 95.54%
# Epoch: 494, Loss: 0.8083, Accuracy: 95.54%
# Epoch: 495, Loss: 0.8082, Accuracy: 95.54%
# Epoch: 496, Loss: 0.8081, Accuracy: 95.54%
# Epoch: 497, Loss: 0.8080, Accuracy: 95.54%
# Epoch: 498, Loss: 0.8079, Accuracy: 95.54%
# Epoch: 499, Loss: 0.8078, Accuracy: 95.54%
# Epoch: 500, Loss: 0.8077, Accuracy: 95.54%
# Epoch: 501, Loss: 0.8076, Accuracy: 95.54%
# Epoch: 502, Loss: 0.8075, Accuracy: 95.54%
# Epoch: 503, Loss: 0.8074, Accuracy: 95.54%
# Epoch: 504, Loss: 0.8073, Accuracy: 95.54%
# Epoch: 505, Loss: 0.8073, Accuracy: 95.54%
# Epoch: 506, Loss: 0.8072, Accuracy: 95.54%
# Epoch: 507, Loss: 0.8071, Accuracy: 95.54%
# Epoch: 508, Loss: 0.8070, Accuracy: 95.54%
# Epoch: 509, Loss: 0.8069, Accuracy: 95.54%
# Epoch: 510, Loss: 0.8068, Accuracy: 95.54%
# Epoch: 511, Loss: 0.8067, Accuracy: 95.54%
# Epoch: 512, Loss: 0.8066, Accuracy: 95.54%
# Epoch: 513, Loss: 0.8065, Accuracy: 95.54%
# Epoch: 514, Loss: 0.8064, Accuracy: 95.54%
# Epoch: 515, Loss: 0.8063, Accuracy: 95.54%
# Epoch: 516, Loss: 0.8062, Accuracy: 95.54%
# Epoch: 517, Loss: 0.8061, Accuracy: 95.54%
# Epoch: 518, Loss: 0.8060, Accuracy: 95.54%
# Epoch: 519, Loss: 0.8059, Accuracy: 95.54%
# Epoch: 520, Loss: 0.8058, Accuracy: 95.54%
# Epoch: 521, Loss: 0.8057, Accuracy: 95.54%
# Epoch: 522, Loss: 0.8056, Accuracy: 95.54%
# Epoch: 523, Loss: 0.8055, Accuracy: 95.54%
# Epoch: 524, Loss: 0.8054, Accuracy: 95.54%
# Epoch: 525, Loss: 0.8053, Accuracy: 95.54%
# Epoch: 526, Loss: 0.8052, Accuracy: 95.54%
# Epoch: 527, Loss: 0.8052, Accuracy: 95.54%
# Epoch: 528, Loss: 0.8051, Accuracy: 95.54%
# Epoch: 529, Loss: 0.8050, Accuracy: 95.54%
# Epoch: 530, Loss: 0.8049, Accuracy: 95.54%
# Epoch: 531, Loss: 0.8048, Accuracy: 95.54%
# Epoch: 532, Loss: 0.8047, Accuracy: 95.54%
# Epoch: 533, Loss: 0.8046, Accuracy: 95.54%
# Epoch: 534, Loss: 0.8045, Accuracy: 95.54%
# Epoch: 535, Loss: 0.8045, Accuracy: 95.54%
# Epoch: 536, Loss: 0.8044, Accuracy: 95.54%
# Epoch: 537, Loss: 0.8043, Accuracy: 95.54%
# Epoch: 538, Loss: 0.8042, Accuracy: 95.54%
# Epoch: 539, Loss: 0.8041, Accuracy: 95.54%
# Epoch: 540, Loss: 0.8040, Accuracy: 95.54%
# Epoch: 541, Loss: 0.8040, Accuracy: 95.54%
# Epoch: 542, Loss: 0.8039, Accuracy: 95.54%
# Epoch: 543, Loss: 0.8038, Accuracy: 95.54%
# Epoch: 544, Loss: 0.8037, Accuracy: 95.54%
# Epoch: 545, Loss: 0.8036, Accuracy: 95.54%
# Epoch: 546, Loss: 0.8035, Accuracy: 95.54%
# Epoch: 547, Loss: 0.8035, Accuracy: 95.54%
# Epoch: 548, Loss: 0.8034, Accuracy: 95.54%
# Epoch: 549, Loss: 0.8033, Accuracy: 95.54%
# Epoch: 550, Loss: 0.8032, Accuracy: 95.54%
# Epoch: 551, Loss: 0.8032, Accuracy: 95.54%
# Epoch: 552, Loss: 0.8031, Accuracy: 95.54%
# Epoch: 553, Loss: 0.8030, Accuracy: 95.54%
# Epoch: 554, Loss: 0.8029, Accuracy: 95.54%
# Epoch: 555, Loss: 0.8029, Accuracy: 95.54%
# Epoch: 556, Loss: 0.8028, Accuracy: 95.54%
# Epoch: 557, Loss: 0.8027, Accuracy: 95.54%
# Epoch: 558, Loss: 0.8026, Accuracy: 95.54%
# Epoch: 559, Loss: 0.8026, Accuracy: 95.54%
# Epoch: 560, Loss: 0.8025, Accuracy: 95.54%
# Epoch: 561, Loss: 0.8024, Accuracy: 95.54%
# Epoch: 562, Loss: 0.8023, Accuracy: 95.54%
# Epoch: 563, Loss: 0.8023, Accuracy: 95.54%
# Epoch: 564, Loss: 0.8022, Accuracy: 95.54%
# Epoch: 565, Loss: 0.8021, Accuracy: 95.54%
# Epoch: 566, Loss: 0.8021, Accuracy: 95.54%
# Epoch: 567, Loss: 0.8020, Accuracy: 95.54%
# Epoch: 568, Loss: 0.8019, Accuracy: 95.54%
# Epoch: 569, Loss: 0.8018, Accuracy: 95.54%
# Epoch: 570, Loss: 0.8018, Accuracy: 95.54%
# Epoch: 571, Loss: 0.8017, Accuracy: 95.54%
# Epoch: 572, Loss: 0.8016, Accuracy: 95.54%
# Epoch: 573, Loss: 0.8016, Accuracy: 95.54%
# Epoch: 574, Loss: 0.8015, Accuracy: 95.54%
# Epoch: 575, Loss: 0.8014, Accuracy: 95.54%
# Epoch: 576, Loss: 0.8014, Accuracy: 95.54%
# Epoch: 577, Loss: 0.8013, Accuracy: 95.54%
# Epoch: 578, Loss: 0.8012, Accuracy: 95.54%
# Epoch: 579, Loss: 0.8012, Accuracy: 95.54%
# Epoch: 580, Loss: 0.8011, Accuracy: 95.54%
# Epoch: 581, Loss: 0.8010, Accuracy: 95.54%
# Epoch: 582, Loss: 0.8010, Accuracy: 95.54%
# Epoch: 583, Loss: 0.8009, Accuracy: 95.54%
# Epoch: 584, Loss: 0.8008, Accuracy: 95.54%
# Epoch: 585, Loss: 0.8008, Accuracy: 95.54%
# Epoch: 586, Loss: 0.8007, Accuracy: 95.54%
# Epoch: 587, Loss: 0.8007, Accuracy: 95.54%
# Epoch: 588, Loss: 0.8006, Accuracy: 95.54%
# Epoch: 589, Loss: 0.8005, Accuracy: 95.54%
# Epoch: 590, Loss: 0.8005, Accuracy: 95.54%
# Epoch: 591, Loss: 0.8004, Accuracy: 95.54%
# Epoch: 592, Loss: 0.8003, Accuracy: 95.54%
# Epoch: 593, Loss: 0.8003, Accuracy: 95.54%
# Epoch: 594, Loss: 0.8002, Accuracy: 95.54%
# Epoch: 595, Loss: 0.8002, Accuracy: 95.54%
# Epoch: 596, Loss: 0.8001, Accuracy: 95.54%
# Epoch: 597, Loss: 0.8000, Accuracy: 95.54%
# Epoch: 598, Loss: 0.7999, Accuracy: 95.54%
# Epoch: 599, Loss: 0.7999, Accuracy: 95.54%
# Epoch: 600, Loss: 0.7998, Accuracy: 95.54%
# Epoch: 601, Loss: 0.7997, Accuracy: 95.54%
# Epoch: 602, Loss: 0.7997, Accuracy: 95.54%
# Epoch: 603, Loss: 0.7996, Accuracy: 95.54%
# Epoch: 604, Loss: 0.7995, Accuracy: 95.54%
# Epoch: 605, Loss: 0.7995, Accuracy: 95.54%
# Epoch: 606, Loss: 0.7994, Accuracy: 95.54%
# Epoch: 607, Loss: 0.7993, Accuracy: 95.54%
# Epoch: 608, Loss: 0.7993, Accuracy: 95.54%
# Epoch: 609, Loss: 0.7992, Accuracy: 95.54%
# Epoch: 610, Loss: 0.7991, Accuracy: 95.54%
# Epoch: 611, Loss: 0.7991, Accuracy: 95.54%
# Epoch: 612, Loss: 0.7990, Accuracy: 95.54%
# Epoch: 613, Loss: 0.7990, Accuracy: 95.54%
# Epoch: 614, Loss: 0.7989, Accuracy: 95.54%
# Epoch: 615, Loss: 0.7989, Accuracy: 95.54%
# Epoch: 616, Loss: 0.7988, Accuracy: 95.54%
# Epoch: 617, Loss: 0.7987, Accuracy: 95.54%
# Epoch: 618, Loss: 0.7987, Accuracy: 95.54%
# Epoch: 619, Loss: 0.7986, Accuracy: 95.54%
# Epoch: 620, Loss: 0.7986, Accuracy: 95.54%
# Epoch: 621, Loss: 0.7985, Accuracy: 95.54%
# Epoch: 622, Loss: 0.7985, Accuracy: 95.54%
# Epoch: 623, Loss: 0.7984, Accuracy: 95.54%
# Epoch: 624, Loss: 0.7983, Accuracy: 95.54%
# Epoch: 625, Loss: 0.7983, Accuracy: 95.54%
# Epoch: 626, Loss: 0.7982, Accuracy: 95.54%
# Epoch: 627, Loss: 0.7982, Accuracy: 95.54%
# Epoch: 628, Loss: 0.7981, Accuracy: 95.54%
# Epoch: 629, Loss: 0.7981, Accuracy: 95.54%
# Epoch: 630, Loss: 0.7980, Accuracy: 95.54%
# Epoch: 631, Loss: 0.7980, Accuracy: 95.54%
# Epoch: 632, Loss: 0.7979, Accuracy: 95.54%
# Epoch: 633, Loss: 0.7979, Accuracy: 95.54%
# Epoch: 634, Loss: 0.7978, Accuracy: 95.54%
# Epoch: 635, Loss: 0.7978, Accuracy: 95.54%
# Epoch: 636, Loss: 0.7977, Accuracy: 95.54%
# Epoch: 637, Loss: 0.7977, Accuracy: 95.54%
# Epoch: 638, Loss: 0.7976, Accuracy: 95.54%
# Epoch: 639, Loss: 0.7976, Accuracy: 95.54%
# Epoch: 640, Loss: 0.7975, Accuracy: 95.54%
# Epoch: 641, Loss: 0.7974, Accuracy: 95.54%
# Epoch: 642, Loss: 0.7974, Accuracy: 95.54%
# Epoch: 643, Loss: 0.7973, Accuracy: 95.54%
# Epoch: 644, Loss: 0.7973, Accuracy: 95.54%
# Epoch: 645, Loss: 0.7973, Accuracy: 95.54%
# Epoch: 646, Loss: 0.7972, Accuracy: 95.54%
# Epoch: 647, Loss: 0.7972, Accuracy: 95.54%
# Epoch: 648, Loss: 0.7971, Accuracy: 95.54%
# Epoch: 649, Loss: 0.7971, Accuracy: 95.54%
# Epoch: 650, Loss: 0.7970, Accuracy: 95.54%
# Epoch: 651, Loss: 0.7970, Accuracy: 95.54%
# Epoch: 652, Loss: 0.7969, Accuracy: 95.54%
# Epoch: 653, Loss: 0.7969, Accuracy: 95.54%
# Epoch: 654, Loss: 0.7968, Accuracy: 95.54%
# Epoch: 655, Loss: 0.7968, Accuracy: 95.54%
# Epoch: 656, Loss: 0.7967, Accuracy: 95.54%
# Epoch: 657, Loss: 0.7967, Accuracy: 95.54%
# Epoch: 658, Loss: 0.7966, Accuracy: 95.54%
# Epoch: 659, Loss: 0.7966, Accuracy: 95.54%
# Epoch: 660, Loss: 0.7965, Accuracy: 95.54%
# Epoch: 661, Loss: 0.7965, Accuracy: 95.54%
# Epoch: 662, Loss: 0.7964, Accuracy: 95.54%
# Epoch: 663, Loss: 0.7964, Accuracy: 95.54%
# Epoch: 664, Loss: 0.7964, Accuracy: 95.54%
# Epoch: 665, Loss: 0.7963, Accuracy: 95.54%
# Epoch: 666, Loss: 0.7963, Accuracy: 95.54%
# Epoch: 667, Loss: 0.7962, Accuracy: 95.54%
# Epoch: 668, Loss: 0.7962, Accuracy: 95.54%
# Epoch: 669, Loss: 0.7961, Accuracy: 95.54%
# Epoch: 670, Loss: 0.7961, Accuracy: 95.54%
# Epoch: 671, Loss: 0.7960, Accuracy: 95.54%
# Epoch: 672, Loss: 0.7960, Accuracy: 95.54%
# Epoch: 673, Loss: 0.7960, Accuracy: 95.54%
# Epoch: 674, Loss: 0.7959, Accuracy: 95.54%
# Epoch: 675, Loss: 0.7959, Accuracy: 95.54%
# Epoch: 676, Loss: 0.7958, Accuracy: 95.54%
# Epoch: 677, Loss: 0.7958, Accuracy: 95.54%
# Epoch: 678, Loss: 0.7958, Accuracy: 95.54%
# Epoch: 679, Loss: 0.7957, Accuracy: 95.54%
# Epoch: 680, Loss: 0.7957, Accuracy: 95.54%
# Epoch: 681, Loss: 0.7956, Accuracy: 95.54%
# Epoch: 682, Loss: 0.7956, Accuracy: 95.54%
# Epoch: 683, Loss: 0.7955, Accuracy: 95.54%
# Epoch: 684, Loss: 0.7955, Accuracy: 95.54%
# Epoch: 685, Loss: 0.7955, Accuracy: 95.54%
# Epoch: 686, Loss: 0.7954, Accuracy: 95.54%
# Epoch: 687, Loss: 0.7954, Accuracy: 95.54%
# Epoch: 688, Loss: 0.7953, Accuracy: 95.54%
# Epoch: 689, Loss: 0.7953, Accuracy: 95.54%
# Epoch: 690, Loss: 0.7953, Accuracy: 95.54%
# Epoch: 691, Loss: 0.7952, Accuracy: 95.54%
# Epoch: 692, Loss: 0.7952, Accuracy: 95.54%
# Epoch: 693, Loss: 0.7951, Accuracy: 95.54%
# Epoch: 694, Loss: 0.7951, Accuracy: 95.54%
# Epoch: 695, Loss: 0.7951, Accuracy: 95.54%
# Epoch: 696, Loss: 0.7950, Accuracy: 95.54%
# Epoch: 697, Loss: 0.7950, Accuracy: 95.54%
# Epoch: 698, Loss: 0.7950, Accuracy: 95.54%
# Epoch: 699, Loss: 0.7949, Accuracy: 95.54%
# Epoch: 700, Loss: 0.7949, Accuracy: 95.54%
# Epoch: 701, Loss: 0.7948, Accuracy: 95.54%
# Epoch: 702, Loss: 0.7948, Accuracy: 95.54%
# Epoch: 703, Loss: 0.7948, Accuracy: 95.54%
# Epoch: 704, Loss: 0.7947, Accuracy: 95.54%
# Epoch: 705, Loss: 0.7947, Accuracy: 95.54%
# Epoch: 706, Loss: 0.7947, Accuracy: 95.54%
# Epoch: 707, Loss: 0.7946, Accuracy: 95.54%
# Epoch: 708, Loss: 0.7946, Accuracy: 95.54%
# Epoch: 709, Loss: 0.7946, Accuracy: 95.54%
# Epoch: 710, Loss: 0.7945, Accuracy: 95.54%
# Epoch: 711, Loss: 0.7945, Accuracy: 95.54%
# Epoch: 712, Loss: 0.7944, Accuracy: 95.54%
# Epoch: 713, Loss: 0.7944, Accuracy: 95.54%
# Epoch: 714, Loss: 0.7944, Accuracy: 95.54%
# Epoch: 715, Loss: 0.7943, Accuracy: 95.54%
# Epoch: 716, Loss: 0.7943, Accuracy: 95.54%
# Epoch: 717, Loss: 0.7943, Accuracy: 95.54%
# Epoch: 718, Loss: 0.7942, Accuracy: 95.54%
# Epoch: 719, Loss: 0.7942, Accuracy: 95.54%
# Epoch: 720, Loss: 0.7942, Accuracy: 95.54%
# Epoch: 721, Loss: 0.7941, Accuracy: 95.54%
# Epoch: 722, Loss: 0.7941, Accuracy: 95.54%
# Epoch: 723, Loss: 0.7941, Accuracy: 95.54%
# Epoch: 724, Loss: 0.7941, Accuracy: 95.54%
# Epoch: 725, Loss: 0.7940, Accuracy: 95.54%
# Epoch: 726, Loss: 0.7940, Accuracy: 95.54%
# Epoch: 727, Loss: 0.7940, Accuracy: 95.54%
# Epoch: 728, Loss: 0.7939, Accuracy: 95.54%
# Epoch: 729, Loss: 0.7939, Accuracy: 95.54%
# Epoch: 730, Loss: 0.7939, Accuracy: 95.54%
# Epoch: 731, Loss: 0.7938, Accuracy: 95.54%
# Epoch: 732, Loss: 0.7938, Accuracy: 95.54%
# Epoch: 733, Loss: 0.7938, Accuracy: 95.54%
# Epoch: 734, Loss: 0.7937, Accuracy: 95.54%
# Epoch: 735, Loss: 0.7937, Accuracy: 95.54%
# Epoch: 736, Loss: 0.7937, Accuracy: 95.54%
# Epoch: 737, Loss: 0.7936, Accuracy: 95.54%
# Epoch: 738, Loss: 0.7936, Accuracy: 95.54%
# Epoch: 739, Loss: 0.7936, Accuracy: 95.54%
# Epoch: 740, Loss: 0.7936, Accuracy: 95.54%
# Epoch: 741, Loss: 0.7935, Accuracy: 95.54%
# Epoch: 742, Loss: 0.7935, Accuracy: 95.54%
# Epoch: 743, Loss: 0.7935, Accuracy: 95.54%
# Epoch: 744, Loss: 0.7934, Accuracy: 95.54%
# Epoch: 745, Loss: 0.7934, Accuracy: 95.54%
# Epoch: 746, Loss: 0.7934, Accuracy: 95.54%
# Epoch: 747, Loss: 0.7934, Accuracy: 95.54%
# Epoch: 748, Loss: 0.7933, Accuracy: 95.54%
# Epoch: 749, Loss: 0.7933, Accuracy: 95.54%
# Epoch: 750, Loss: 0.7933, Accuracy: 95.54%
# Epoch: 751, Loss: 0.7932, Accuracy: 95.54%
# Epoch: 752, Loss: 0.7932, Accuracy: 95.54%
# Epoch: 753, Loss: 0.7932, Accuracy: 95.54%
# Epoch: 754, Loss: 0.7932, Accuracy: 95.54%
# Epoch: 755, Loss: 0.7931, Accuracy: 95.54%
# Epoch: 756, Loss: 0.7931, Accuracy: 95.54%
# Epoch: 757, Loss: 0.7931, Accuracy: 95.54%
# Epoch: 758, Loss: 0.7930, Accuracy: 95.54%
# Epoch: 759, Loss: 0.7930, Accuracy: 95.54%
# Epoch: 760, Loss: 0.7930, Accuracy: 95.54%
# Epoch: 761, Loss: 0.7930, Accuracy: 95.54%
# Epoch: 762, Loss: 0.7929, Accuracy: 95.54%
# Epoch: 763, Loss: 0.7929, Accuracy: 95.54%
# Epoch: 764, Loss: 0.7929, Accuracy: 95.54%
# Epoch: 765, Loss: 0.7929, Accuracy: 95.54%
# Epoch: 766, Loss: 0.7928, Accuracy: 95.54%
# Epoch: 767, Loss: 0.7928, Accuracy: 95.54%
# Epoch: 768, Loss: 0.7928, Accuracy: 95.54%
# Epoch: 769, Loss: 0.7928, Accuracy: 95.54%
# Epoch: 770, Loss: 0.7927, Accuracy: 95.54%
# Epoch: 771, Loss: 0.7927, Accuracy: 95.54%
# Epoch: 772, Loss: 0.7927, Accuracy: 95.54%
# Epoch: 773, Loss: 0.7926, Accuracy: 95.54%
# Epoch: 774, Loss: 0.7926, Accuracy: 95.54%
# Epoch: 775, Loss: 0.7926, Accuracy: 95.54%
# Epoch: 776, Loss: 0.7926, Accuracy: 95.54%
# Epoch: 777, Loss: 0.7925, Accuracy: 95.54%
# Epoch: 778, Loss: 0.7925, Accuracy: 95.54%
# Epoch: 779, Loss: 0.7925, Accuracy: 95.54%
# Epoch: 780, Loss: 0.7925, Accuracy: 95.54%
# Epoch: 781, Loss: 0.7925, Accuracy: 95.54%
# Epoch: 782, Loss: 0.7924, Accuracy: 95.54%
# Epoch: 783, Loss: 0.7924, Accuracy: 95.54%
# Epoch: 784, Loss: 0.7924, Accuracy: 95.54%
# Epoch: 785, Loss: 0.7924, Accuracy: 95.54%
# Epoch: 786, Loss: 0.7923, Accuracy: 95.54%
# Epoch: 787, Loss: 0.7923, Accuracy: 95.54%
# Epoch: 788, Loss: 0.7923, Accuracy: 95.54%
# Epoch: 789, Loss: 0.7923, Accuracy: 95.54%
# Epoch: 790, Loss: 0.7922, Accuracy: 95.54%
# Epoch: 791, Loss: 0.7922, Accuracy: 95.54%
# Epoch: 792, Loss: 0.7922, Accuracy: 95.54%
# Epoch: 793, Loss: 0.7922, Accuracy: 95.54%
# Epoch: 794, Loss: 0.7921, Accuracy: 95.54%
# Epoch: 795, Loss: 0.7921, Accuracy: 95.54%
# Epoch: 796, Loss: 0.7921, Accuracy: 95.54%
# Epoch: 797, Loss: 0.7921, Accuracy: 95.54%
# Epoch: 798, Loss: 0.7920, Accuracy: 95.54%
# Epoch: 799, Loss: 0.7920, Accuracy: 95.54%
# Epoch: 800, Loss: 0.7920, Accuracy: 95.54%
# Epoch: 801, Loss: 0.7920, Accuracy: 95.54%
# Epoch: 802, Loss: 0.7920, Accuracy: 95.54%
# Epoch: 803, Loss: 0.7919, Accuracy: 95.54%
# Epoch: 804, Loss: 0.7919, Accuracy: 95.54%
# Epoch: 805, Loss: 0.7919, Accuracy: 95.54%
# Epoch: 806, Loss: 0.7919, Accuracy: 95.54%
# Epoch: 807, Loss: 0.7918, Accuracy: 95.54%
# Epoch: 808, Loss: 0.7918, Accuracy: 95.54%
# Epoch: 809, Loss: 0.7918, Accuracy: 95.54%
# Epoch: 810, Loss: 0.7918, Accuracy: 95.54%
# Epoch: 811, Loss: 0.7917, Accuracy: 95.54%
# Epoch: 812, Loss: 0.7917, Accuracy: 95.54%
# Epoch: 813, Loss: 0.7917, Accuracy: 95.54%
# Epoch: 814, Loss: 0.7917, Accuracy: 95.54%
# Epoch: 815, Loss: 0.7917, Accuracy: 95.54%
# Epoch: 816, Loss: 0.7916, Accuracy: 95.54%
# Epoch: 817, Loss: 0.7916, Accuracy: 95.54%
# Epoch: 818, Loss: 0.7916, Accuracy: 95.54%
# Epoch: 819, Loss: 0.7916, Accuracy: 95.54%
# Epoch: 820, Loss: 0.7915, Accuracy: 95.54%
# Epoch: 821, Loss: 0.7915, Accuracy: 95.54%
# Epoch: 822, Loss: 0.7915, Accuracy: 95.54%
# Epoch: 823, Loss: 0.7915, Accuracy: 95.54%
# Epoch: 824, Loss: 0.7915, Accuracy: 95.54%
# Epoch: 825, Loss: 0.7914, Accuracy: 95.54%
# Epoch: 826, Loss: 0.7914, Accuracy: 95.54%
# Epoch: 827, Loss: 0.7914, Accuracy: 95.54%
# Epoch: 828, Loss: 0.7914, Accuracy: 95.54%
# Epoch: 829, Loss: 0.7914, Accuracy: 95.54%
# Epoch: 830, Loss: 0.7913, Accuracy: 95.54%
# Epoch: 831, Loss: 0.7913, Accuracy: 95.54%
# Epoch: 832, Loss: 0.7913, Accuracy: 95.54%
# Epoch: 833, Loss: 0.7913, Accuracy: 95.54%
# Epoch: 834, Loss: 0.7912, Accuracy: 95.54%
# Epoch: 835, Loss: 0.7912, Accuracy: 95.54%
# Epoch: 836, Loss: 0.7912, Accuracy: 95.54%
# Epoch: 837, Loss: 0.7912, Accuracy: 95.54%
# Epoch: 838, Loss: 0.7912, Accuracy: 95.54%
# Epoch: 839, Loss: 0.7911, Accuracy: 95.54%
# Epoch: 840, Loss: 0.7911, Accuracy: 95.54%
# Epoch: 841, Loss: 0.7911, Accuracy: 95.54%
# Epoch: 842, Loss: 0.7911, Accuracy: 95.54%
# Epoch: 843, Loss: 0.7911, Accuracy: 95.54%
# Epoch: 844, Loss: 0.7910, Accuracy: 95.54%
# Epoch: 845, Loss: 0.7910, Accuracy: 95.54%
# Epoch: 846, Loss: 0.7910, Accuracy: 95.54%
# Epoch: 847, Loss: 0.7910, Accuracy: 95.54%
# Epoch: 848, Loss: 0.7909, Accuracy: 95.54%
# Epoch: 849, Loss: 0.7909, Accuracy: 95.54%
# Epoch: 850, Loss: 0.7909, Accuracy: 95.54%
# Epoch: 851, Loss: 0.7909, Accuracy: 95.54%
# Epoch: 852, Loss: 0.7908, Accuracy: 95.54%
# Epoch: 853, Loss: 0.7908, Accuracy: 95.54%
# Epoch: 854, Loss: 0.7908, Accuracy: 95.54%
# Epoch: 855, Loss: 0.7908, Accuracy: 95.54%
# Epoch: 856, Loss: 0.7908, Accuracy: 95.54%
# Epoch: 857, Loss: 0.7907, Accuracy: 95.54%
# Epoch: 858, Loss: 0.7907, Accuracy: 95.54%
# Epoch: 859, Loss: 0.7907, Accuracy: 95.54%
# Epoch: 860, Loss: 0.7907, Accuracy: 95.54%
# Epoch: 861, Loss: 0.7906, Accuracy: 95.54%
# Epoch: 862, Loss: 0.7906, Accuracy: 95.54%
# Epoch: 863, Loss: 0.7906, Accuracy: 95.54%
# Epoch: 864, Loss: 0.7906, Accuracy: 95.54%
# Epoch: 865, Loss: 0.7906, Accuracy: 95.54%
# Epoch: 866, Loss: 0.7905, Accuracy: 95.54%
# Epoch: 867, Loss: 0.7905, Accuracy: 95.54%
# Epoch: 868, Loss: 0.7905, Accuracy: 95.54%
# Epoch: 869, Loss: 0.7905, Accuracy: 95.54%
# Epoch: 870, Loss: 0.7904, Accuracy: 95.54%
# Epoch: 871, Loss: 0.7904, Accuracy: 95.54%
# Epoch: 872, Loss: 0.7904, Accuracy: 95.54%
# Epoch: 873, Loss: 0.7904, Accuracy: 95.54%
# Epoch: 874, Loss: 0.7904, Accuracy: 95.54%
# Epoch: 875, Loss: 0.7903, Accuracy: 95.54%
# Epoch: 876, Loss: 0.7903, Accuracy: 95.54%
# Epoch: 877, Loss: 0.7903, Accuracy: 95.54%
# Epoch: 878, Loss: 0.7903, Accuracy: 95.54%
# Epoch: 879, Loss: 0.7903, Accuracy: 95.54%
# Epoch: 880, Loss: 0.7902, Accuracy: 95.54%
# Epoch: 881, Loss: 0.7902, Accuracy: 95.54%
# Epoch: 882, Loss: 0.7902, Accuracy: 95.54%
# Epoch: 883, Loss: 0.7902, Accuracy: 95.54%
# Epoch: 884, Loss: 0.7902, Accuracy: 95.54%
# Epoch: 885, Loss: 0.7901, Accuracy: 95.54%
# Epoch: 886, Loss: 0.7901, Accuracy: 95.54%
# Epoch: 887, Loss: 0.7901, Accuracy: 95.54%
# Epoch: 888, Loss: 0.7901, Accuracy: 95.54%
# Epoch: 889, Loss: 0.7901, Accuracy: 95.54%
# Epoch: 890, Loss: 0.7900, Accuracy: 95.54%
# Epoch: 891, Loss: 0.7900, Accuracy: 95.54%
# Epoch: 892, Loss: 0.7900, Accuracy: 95.54%
# Epoch: 893, Loss: 0.7900, Accuracy: 95.54%
# Epoch: 894, Loss: 0.7900, Accuracy: 95.54%
# Epoch: 895, Loss: 0.7899, Accuracy: 95.54%
# Epoch: 896, Loss: 0.7899, Accuracy: 95.54%
# Epoch: 897, Loss: 0.7899, Accuracy: 95.54%
# Epoch: 898, Loss: 0.7899, Accuracy: 95.54%
# Epoch: 899, Loss: 0.7899, Accuracy: 95.54%
# Epoch: 900, Loss: 0.7899, Accuracy: 95.54%
# Epoch: 901, Loss: 0.7898, Accuracy: 95.54%
# Epoch: 902, Loss: 0.7898, Accuracy: 95.54%
# Epoch: 903, Loss: 0.7898, Accuracy: 95.54%
# Epoch: 904, Loss: 0.7898, Accuracy: 95.54%
# Epoch: 905, Loss: 0.7898, Accuracy: 95.54%
# Epoch: 906, Loss: 0.7897, Accuracy: 95.54%
# Epoch: 907, Loss: 0.7897, Accuracy: 95.54%
# Epoch: 908, Loss: 0.7897, Accuracy: 95.54%
# Epoch: 909, Loss: 0.7897, Accuracy: 95.54%
# Epoch: 910, Loss: 0.7897, Accuracy: 95.54%
# Epoch: 911, Loss: 0.7896, Accuracy: 95.54%
# Epoch: 912, Loss: 0.7896, Accuracy: 95.54%
# Epoch: 913, Loss: 0.7896, Accuracy: 95.54%
# Epoch: 914, Loss: 0.7896, Accuracy: 95.54%
# Epoch: 915, Loss: 0.7896, Accuracy: 95.54%
# Epoch: 916, Loss: 0.7896, Accuracy: 95.54%
# Epoch: 917, Loss: 0.7895, Accuracy: 95.54%
# Epoch: 918, Loss: 0.7895, Accuracy: 95.54%
# Epoch: 919, Loss: 0.7895, Accuracy: 95.54%
# Epoch: 920, Loss: 0.7895, Accuracy: 95.54%
# Epoch: 921, Loss: 0.7895, Accuracy: 95.54%
# Epoch: 922, Loss: 0.7895, Accuracy: 95.54%
# Epoch: 923, Loss: 0.7894, Accuracy: 95.54%
# Epoch: 924, Loss: 0.7894, Accuracy: 95.54%
# Epoch: 925, Loss: 0.7894, Accuracy: 95.54%
# Epoch: 926, Loss: 0.7894, Accuracy: 95.54%
# Epoch: 927, Loss: 0.7894, Accuracy: 95.54%
# Epoch: 928, Loss: 0.7893, Accuracy: 95.54%
# Epoch: 929, Loss: 0.7893, Accuracy: 95.54%
# Epoch: 930, Loss: 0.7893, Accuracy: 95.54%
# Epoch: 931, Loss: 0.7893, Accuracy: 95.54%
# Epoch: 932, Loss: 0.7893, Accuracy: 95.54%
# Epoch: 933, Loss: 0.7892, Accuracy: 95.54%
# Epoch: 934, Loss: 0.7892, Accuracy: 95.54%
# Epoch: 935, Loss: 0.7892, Accuracy: 95.54%
# Epoch: 936, Loss: 0.7892, Accuracy: 95.54%
# Epoch: 937, Loss: 0.7892, Accuracy: 95.54%
# Epoch: 938, Loss: 0.7891, Accuracy: 95.54%
# Epoch: 939, Loss: 0.7891, Accuracy: 95.54%
# Epoch: 940, Loss: 0.7891, Accuracy: 95.54%
# Epoch: 941, Loss: 0.7891, Accuracy: 95.54%
# Epoch: 942, Loss: 0.7890, Accuracy: 95.54%
# Epoch: 943, Loss: 0.7890, Accuracy: 95.54%
# Epoch: 944, Loss: 0.7890, Accuracy: 95.54%
# Epoch: 945, Loss: 0.7889, Accuracy: 95.54%
# Epoch: 946, Loss: 0.7889, Accuracy: 95.54%
# Epoch: 947, Loss: 0.7889, Accuracy: 95.54%
# Epoch: 948, Loss: 0.7888, Accuracy: 95.54%
# Epoch: 949, Loss: 0.7888, Accuracy: 95.54%
# Epoch: 950, Loss: 0.7888, Accuracy: 95.54%
# Epoch: 951, Loss: 0.7887, Accuracy: 95.54%
# Epoch: 952, Loss: 0.7887, Accuracy: 95.54%
# Epoch: 953, Loss: 0.7886, Accuracy: 95.54%
# Epoch: 954, Loss: 0.7886, Accuracy: 95.54%
# Epoch: 955, Loss: 0.7885, Accuracy: 95.54%
# Epoch: 956, Loss: 0.7885, Accuracy: 95.54%
# Epoch: 957, Loss: 0.7884, Accuracy: 95.54%
# Epoch: 958, Loss: 0.7883, Accuracy: 95.54%
# Epoch: 959, Loss: 0.7882, Accuracy: 95.54%
# Epoch: 960, Loss: 0.7882, Accuracy: 95.54%
# Epoch: 961, Loss: 0.7881, Accuracy: 95.54%
# Epoch: 962, Loss: 0.7880, Accuracy: 95.54%
# Epoch: 963, Loss: 0.7879, Accuracy: 95.54%
# Epoch: 964, Loss: 0.7878, Accuracy: 95.54%
# Epoch: 965, Loss: 0.7877, Accuracy: 95.54%
# Epoch: 966, Loss: 0.7876, Accuracy: 95.54%
# Epoch: 967, Loss: 0.7875, Accuracy: 95.54%
# Epoch: 968, Loss: 0.7874, Accuracy: 96.43%
# Epoch: 969, Loss: 0.7872, Accuracy: 96.43%
# Epoch: 970, Loss: 0.7871, Accuracy: 96.43%
# Epoch: 971, Loss: 0.7870, Accuracy: 96.43%
# Epoch: 972, Loss: 0.7869, Accuracy: 96.43%
# Epoch: 973, Loss: 0.7868, Accuracy: 96.43%
# Epoch: 974, Loss: 0.7867, Accuracy: 96.43%
# Epoch: 975, Loss: 0.7866, Accuracy: 96.43%
# Epoch: 976, Loss: 0.7865, Accuracy: 96.43%
# Epoch: 977, Loss: 0.7864, Accuracy: 96.43%
# Epoch: 978, Loss: 0.7863, Accuracy: 96.43%
# Epoch: 979, Loss: 0.7862, Accuracy: 96.43%
# Epoch: 980, Loss: 0.7861, Accuracy: 96.43%
# Epoch: 981, Loss: 0.7860, Accuracy: 96.43%
# Epoch: 982, Loss: 0.7859, Accuracy: 96.43%
# Epoch: 983, Loss: 0.7859, Accuracy: 96.43%
# Epoch: 984, Loss: 0.7858, Accuracy: 96.43%
# Epoch: 985, Loss: 0.7857, Accuracy: 96.43%
# Epoch: 986, Loss: 0.7856, Accuracy: 96.43%
# Epoch: 987, Loss: 0.7856, Accuracy: 96.43%
# Epoch: 988, Loss: 0.7855, Accuracy: 96.43%
# Epoch: 989, Loss: 0.7854, Accuracy: 96.43%
# Epoch: 990, Loss: 0.7854, Accuracy: 96.43%
# Epoch: 991, Loss: 0.7853, Accuracy: 96.43%
# Epoch: 992, Loss: 0.7853, Accuracy: 96.43%
# Epoch: 993, Loss: 0.7852, Accuracy: 96.43%
# Epoch: 994, Loss: 0.7851, Accuracy: 96.43%
# Epoch: 995, Loss: 0.7851, Accuracy: 96.43%
# Epoch: 996, Loss: 0.7850, Accuracy: 96.43%
# Epoch: 997, Loss: 0.7850, Accuracy: 96.43%
# Epoch: 998, Loss: 0.7849, Accuracy: 96.43%
# Epoch: 999, Loss: 0.7849, Accuracy: 96.43%
# Epoch: 1000, Loss: 0.7849, Accuracy: 96.43%
# Test Accuracy: 83.59%

# %%
# %%
def translate(array):
    arr = []
    for e in array:
        arr.append(torch.argmax(e))
    return arr
print(f"output 0: {translate(output0)}, \n Y:       {translate(Y)}, \n output 1: {translate(output1)}, \n Y1:       {translate(Y1)}")

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 6), subplot_kw={"xticks": [], "yticks": []})
for i in range(0, 4):
    ax[i // 2, i % 2].imshow(X1.detach().cpu().numpy()[i].reshape(4, 4), aspect="equal")
    if torch.argmax(output1[i]) == 0:
        ax[i // 2, i % 2].set_title(f"The CNN predicts this is {a}")
    if torch.argmax(output1[i]) == 1:
        ax[i // 2, i % 2].set_title(f"The CNN predicts this is {b}")
    if torch.argmax(output1[i]) == 2:
        ax[i // 2, i % 2].set_title(f"The CNN predicts this is {c}")
    if torch.argmax(output1[i]) == 3:
        ax[i // 2, i % 2].set_title(f"The CNN predicts this is {d}")
plt.subplots_adjust(wspace=0.1, hspace=0.5)

# %%
num_rows = 10
num_cols = 10
fig, ax = plt.subplots(num_rows, num_cols, figsize=(20, 20),
                       subplot_kw={"xticks": [], "yticks": []})

for i in range(num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    
    if i < len(x_test) and i < len(output1):
      ax[row, col].imshow(x_test[i].reshape(28, 28), aspect="equal")

      if torch.argmax(output1[i]) == 0:
          ax[row, col].set_title(f"CNN: {a}")
      elif torch.argmax(output1[i]) == 1:
          ax[row, col].set_title(f"CNN: {b}")
      elif torch.argmax(output1[i]) == 2:
          ax[row, col].set_title(f"CNN: {c}")
      elif torch.argmax(output1[i]) == 3:
          ax[row, col].set_title(f"CNN: {d}")
    else:
        ax[row, col].axis('off')

plt.subplots_adjust(wspace=0.1, hspace=0.5)
plt.show()
# Out:
# output 0: [tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0')],
#  Y:       [tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0')],
#  output 1: [tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0')],
#  Y1:       [tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0')]
