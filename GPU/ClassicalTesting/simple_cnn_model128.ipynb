# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.nn import Linear, Softmax, Sigmoid, Module
from scipy.optimize import minimize
from IPython.display import clear_output

# Creating/Formatting Data

import tensorflow as tf
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train[..., np.newaxis]/(255.0/np.pi), x_test[..., np.newaxis]/(255.0/np.pi)
print("Number of original training examples:", len(x_train))
print("Number of original test examples:", len(x_test))

# Filter Values
a = 3
b = 4
c = 5
d = 6
def filter_abcd(x, y):
    keep = (y == a) | (y == b) | (y == c) | (y == d)
    x, y = x[keep], y[keep]
    return x,y

# Filtering using previous method.
x_train, y_train = filter_abcd(x_train, y_train)
x_test, y_test = filter_abcd(x_test, y_test)

print("Number of filtered training examples:", len(x_train))
print("Number of filtered test examples:", len(x_test))

# Displaying Sample Image
img = 13
print(y_train[img])
plt.imshow(x_train[img, :, :, 0])
plt.colorbar()

# Resizing (Quantum Computing Simulation Limit)
x_train_small = tf.image.resize(x_train, (4,4), method = 'area').numpy()
x_test_small = tf.image.resize(x_test, (4,4), method = 'area').numpy()

# Displaying Image Sample After Resizing
img = 13
print(y_train[img])
plt.imshow(x_train_small[img,:,:,0], vmin=0, vmax=np.pi)
plt.colorbar()

# Formatting Helper Methods
def format_data(a,b):
    x_reshaped = []
    x1_reshaped = []

    for g in a:
        x_reshaped.append(g.reshape(1,16))

    for g in b:
        x1_reshaped.append(g.reshape(1,16))

    final_x = []
    final_x1 = []

    for entry in x_reshaped:
        final_x.append(entry[0])

    for entry in x1_reshaped:
        final_x1.append(entry[0])
    return final_x, final_x1

def format_labels(y):
    y_temp = []
    for entry in y:
        if entry == a:
            y_temp.append(0)
        elif entry == b:
            y_temp.append(1)
        elif entry == c:
            y_temp.append(2)
        elif entry == d:
            y_temp.append(3)
    return y_temp

x,x1 = format_data(x_train_small, x_test_small)

# Easier to work with names
y = y_train
y1 = y_test

# Setting labels to 0,1,2,3 for easy reference later
y = format_labels(y)
y1 = format_labels(y1)

# Converting to nparray
x = np.asarray(x)
y = np.asarray(y)
x1 = np.asarray(x1)
y1 = np.asarray(y1)

# Limiting training dataset to lower training time.
x = x[0:128]
y = y[0:128]
x1 = x1[0:128]
y1 = y1[0:128]
print(x)
print(y)

# Additional Helper Functions
def count(y):
    counta = 0
    countb = 0
    countc = 0
    countd = 0
    for i in range(len(y)):
        if y[i] == 0:
            counta+=1
        elif y[i] == 1:
            countb+=1
        elif y[i] == 2:
            countc+=1
        elif y[i] == 3:
            countd+=1
    return(counta, countb, countc, countd)

def balance_lists(x, y, max_count):
    """Balances two lists x and y based on the values in y (0 or 1)."""
    
    x_balanced = []
    y_balanced = []
    count0 = 0
    count1 = 0
    count2 = 0
    count3 = 0

    for i in range(len(y)):
        if y[i] == 0:
            if count0 < max_count:
                x_balanced.append(x[i])
                y_balanced.append(y[i])
                count0 += 1
        elif y[i] == 1:
            if count1 < max_count:
                x_balanced.append(x[i])
                y_balanced.append(y[i])
                count1 += 1
        elif y[i] == 2:
            if count2 < max_count:
                x_balanced.append(x[i])
                y_balanced.append(y[i])
                count2 += 1
        elif y[i] == 3:
            if count3 < max_count:
                x_balanced.append(x[i])
                y_balanced.append(y[i])
                count3 += 1
    return x_balanced, y_balanced

def shuffle(arr1, arr2):
    assert len(arr1) == len(arr2)
    p = np.random.permutation(len(arr1))
    return arr1[p], arr2[p]

# Further Data Cleaning Using Helper Functions
nums = count(y)
print("original:", nums)
max_count = min(nums)
print("max_count =", max_count)
x,y = balance_lists(x, y, max_count)

print("balanced:", count(y))

# Converting to nparray
x = np.asarray(x)
y = np.asarray(y)
x1 = np.asarray(x1)
y1 = np.asarray(y1)
objective_func_vals = []

x,y = shuffle(x,y)
print("shuffled:", count(y))

print("final:", x)
print(y)

# Tensor for Pytorch
X = torch.tensor(x, dtype=torch.float32).to("cuda").reshape(-1, 1, 4, 4)
Y = torch.tensor(y, dtype=torch.long).to("cuda")
X1 = torch.tensor(x1, dtype=torch.float32).to("cuda").reshape(-1, 1, 4, 4)
Y1 = torch.tensor(y1, dtype=torch.long).to("cuda")

# One-Hot Encoding for Final Processing
num_classes = 4
Y = (torch.nn.functional.one_hot(Y, num_classes=num_classes).float())
Y1 = (torch.nn.functional.one_hot(Y1, num_classes=num_classes).float())

print(X.shape,Y.shape,X1.shape,Y1.shape)

# Training

import torch
import torch.nn as nn
import torch.nn.functional as F

# Simplified CNN Model
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=4):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=4, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(4 * 2 * 2, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = x.view(-1, 4 * 2 * 2)
        x = self.fc1(x)
        return x

# Create an instance of the model
model = SimpleCNN().to("cuda")

# Loss Function and Optimizer
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# Accuracy Function
def accuracy(output, y):
    preds = torch.argmax(output, dim=1)
    true = torch.argmax(y, dim=1)
    correct = (preds == true).sum().item()
    return (correct / y.size(0)) * 100

# Training Loop
def train(model, X, Y, X1, Y1, optimizer, loss_function, epochs=100, batch_size=8):
    model.train()
    loss_list = []
    train_acc_list = []
    test_acc_list = []
    for epoch in range(epochs):
        for i in range(0, X.size(0), batch_size):
            X_batch = X[i:i + batch_size]
            Y_batch = Y[i:i + batch_size]

            # Forward pass
            output = model(X_batch)
            loss = loss_function(output, Y_batch)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # Calculate loss and accuracy for the entire epoch (optional, for monitoring)
        with torch.no_grad():
            #Train Data
            output = model(X)
            epoch_loss = loss_function(output, Y).item()
            epoch_train_acc = accuracy(output, Y)
            
            #Test Data
            test_output = model(X1)
            epoch_test_acc = accuracy(test_output, Y1)
            
            loss_list.append(epoch_loss)
            train_acc_list.append(epoch_train_acc)
            test_acc_list.append(epoch_test_acc)
            
            print(f"Epoch: {epoch+1}, Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_train_acc:.2f}%, Test Accuracy: {epoch_test_acc:.2f}%")
    return loss_list, train_acc_list, test_acc_list

# Train the Model
loss_list, acc_list, test_acc_list = train(model, X, Y, X1, Y1, optimizer, loss_function, epochs=100)

# Plot Loss and Accuracy
plt.figure(figsize=(15, 4))
plt.subplot(1, 3, 1)
plt.plot(loss_list)
plt.title("Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.subplot(1, 3, 2)
plt.plot(acc_list)
plt.title("Training Accuracy over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")

plt.subplot(1, 3, 3)
plt.plot(test_acc_list)
plt.title("Test Accuracy over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")


plt.tight_layout()
plt.show()

# Evaluate on Test Data
model.eval()
with torch.no_grad():
    output0 = model(X)
    output1 = model(X1)
    test_acc = accuracy(output1, Y1)
    print(f"Final Test Accuracy: {test_acc:.2f}%")

# Save the Model
torch.save(model.state_dict(), "simple_cnn_model128.pth")
# Out:
# 2025-01-20 16:05:41.817306: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737417941.907745   55798 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737417941.931055   55798 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-20 16:05:42.142562: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Number of original training examples: 60000
# Number of original test examples: 10000
# Number of filtered training examples: 23312
# Number of filtered test examples: 3842
# 6
# I0000 00:00:1737417945.574444   55798 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# 6
# [[0.         0.19058241 0.5850729  ... 1.2083628  0.15663964 0.        ]
#  [0.0359542  0.         0.04701703 ... 0.         0.54685587 0.        ]
#  [0.         0.26902792 0.86968946 ... 1.3765682  0.4684103  0.        ]
#  ...
#  [0.         0.21999948 1.2091172  ... 0.9302835  0.07215983 0.        ]
#  [0.         0.00553142 0.68262696 ... 0.99364346 0.57375866 0.        ]
#  [0.         0.         0.17826243 ... 0.16342819 0.2768222  0.        ]]
# [2 1 0 1 0 2 0 3 3 1 1 0 0 3 2 3 3 0 2 0 0 1 1 1 1 3 1 2 3 3 0 3 0 1 3 1 3
#  0 2 3 0 0 1 3 1 3 0 1 2 0 0 2 1 1 2 3 0 1 3 3 0 1 1 3 1 2 2 0 0 2 3 2 1 0
#  0 3 0 0 1 3 2 3 1 0 0 2 1 3 2 3 0 2 0 0 0 3 1 2 3 2 1 1 2 3 1 2 0 0 2 3 2
#  1 0 1 1 1 0 3 3 2 3 1 2 0 3 0 2 1]
# original: (36, 34, 26, 32)
# max_count = 26
# balanced: (26, 26, 26, 26)
# shuffled: (26, 26, 26, 26)
# final: [[0.0000000e+00 1.5613678e-01 5.3730160e-01 ... 1.1698945e+00
#   5.9362143e-01 0.0000000e+00]
#  [0.0000000e+00 4.5005608e-02 4.0857050e-01 ... 0.0000000e+00
#   1.0446832e+00 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 2.2628519e-03 ... 5.0713027e-01
#   2.3961087e-01 0.0000000e+00]
#  ...
#  [0.0000000e+00 0.0000000e+00 3.3867350e-01 ... 7.7490103e-01
#   2.6223940e-01 0.0000000e+00]
#  [5.8582719e-02 3.8493621e-01 1.2571398e-03 ... 1.9234240e-01
#   8.1588376e-01 2.6777080e-01]
#  [0.0000000e+00 2.4966800e-01 7.5252402e-01 ... 1.3959281e+00
#   5.0084454e-01 0.0000000e+00]]
# [0 1 2 1 2 2 3 3 2 1 2 2 1 0 3 2 3 2 1 1 1 3 1 0 3 1 2 1 3 3 2 0 3 0 1 3 3
#  2 3 1 3 2 0 1 3 0 0 2 2 3 1 0 0 0 2 3 1 0 2 3 0 2 3 1 0 3 0 3 3 1 0 3 1 1
#  0 0 2 0 3 1 1 0 0 0 1 2 3 0 1 1 2 2 3 3 2 2 1 2 0 2 1 2 0 0]
# torch.Size([104, 1, 4, 4]) torch.Size([104, 4]) torch.Size([128, 1, 4, 4]) torch.Size([128, 4])
# Epoch: 1, Loss: 1.3705, Train Accuracy: 25.00%, Test Accuracy: 19.53%
# Epoch: 2, Loss: 1.3135, Train Accuracy: 48.08%, Test Accuracy: 40.62%
# Epoch: 3, Loss: 1.2201, Train Accuracy: 49.04%, Test Accuracy: 41.41%
# Epoch: 4, Loss: 1.1075, Train Accuracy: 55.77%, Test Accuracy: 46.88%
# Epoch: 5, Loss: 0.9961, Train Accuracy: 56.73%, Test Accuracy: 52.34%
# Epoch: 6, Loss: 0.8951, Train Accuracy: 65.38%, Test Accuracy: 57.81%
# Epoch: 7, Loss: 0.8121, Train Accuracy: 70.19%, Test Accuracy: 64.06%
# Epoch: 8, Loss: 0.7452, Train Accuracy: 75.96%, Test Accuracy: 68.75%
# Epoch: 9, Loss: 0.6910, Train Accuracy: 78.85%, Test Accuracy: 71.09%
# Epoch: 10, Loss: 0.6461, Train Accuracy: 81.73%, Test Accuracy: 74.22%
# Epoch: 11, Loss: 0.6082, Train Accuracy: 82.69%, Test Accuracy: 75.00%
# Epoch: 12, Loss: 0.5754, Train Accuracy: 84.62%, Test Accuracy: 75.78%
# Epoch: 13, Loss: 0.5464, Train Accuracy: 84.62%, Test Accuracy: 77.34%
# Epoch: 14, Loss: 0.5214, Train Accuracy: 84.62%, Test Accuracy: 76.56%
# Epoch: 15, Loss: 0.4991, Train Accuracy: 85.58%, Test Accuracy: 76.56%
# Epoch: 16, Loss: 0.4787, Train Accuracy: 85.58%, Test Accuracy: 76.56%
# Epoch: 17, Loss: 0.4605, Train Accuracy: 85.58%, Test Accuracy: 76.56%
# Epoch: 18, Loss: 0.4438, Train Accuracy: 85.58%, Test Accuracy: 77.34%
# Epoch: 19, Loss: 0.4280, Train Accuracy: 87.50%, Test Accuracy: 77.34%
# Epoch: 20, Loss: 0.4140, Train Accuracy: 88.46%, Test Accuracy: 77.34%
# Epoch: 21, Loss: 0.4007, Train Accuracy: 88.46%, Test Accuracy: 78.12%
# Epoch: 22, Loss: 0.3890, Train Accuracy: 88.46%, Test Accuracy: 78.12%
# Epoch: 23, Loss: 0.3771, Train Accuracy: 90.38%, Test Accuracy: 78.12%
# Epoch: 24, Loss: 0.3668, Train Accuracy: 90.38%, Test Accuracy: 78.12%
# Epoch: 25, Loss: 0.3572, Train Accuracy: 91.35%, Test Accuracy: 78.12%
# Epoch: 26, Loss: 0.3471, Train Accuracy: 91.35%, Test Accuracy: 78.12%
# Epoch: 27, Loss: 0.3376, Train Accuracy: 91.35%, Test Accuracy: 78.12%
# Epoch: 28, Loss: 0.3291, Train Accuracy: 91.35%, Test Accuracy: 78.12%
# Epoch: 29, Loss: 0.3208, Train Accuracy: 91.35%, Test Accuracy: 78.12%
# Epoch: 30, Loss: 0.3142, Train Accuracy: 92.31%, Test Accuracy: 78.12%
# Epoch: 31, Loss: 0.3067, Train Accuracy: 91.35%, Test Accuracy: 78.12%
# Epoch: 32, Loss: 0.2996, Train Accuracy: 92.31%, Test Accuracy: 78.12%
# Epoch: 33, Loss: 0.2948, Train Accuracy: 92.31%, Test Accuracy: 78.12%
# Epoch: 34, Loss: 0.2875, Train Accuracy: 92.31%, Test Accuracy: 78.12%
# Epoch: 35, Loss: 0.2827, Train Accuracy: 91.35%, Test Accuracy: 77.34%
# Epoch: 36, Loss: 0.2766, Train Accuracy: 93.27%, Test Accuracy: 78.91%
# Epoch: 37, Loss: 0.2710, Train Accuracy: 93.27%, Test Accuracy: 78.12%
# Epoch: 38, Loss: 0.2658, Train Accuracy: 93.27%, Test Accuracy: 78.91%
# Epoch: 39, Loss: 0.2610, Train Accuracy: 93.27%, Test Accuracy: 78.91%
# Epoch: 40, Loss: 0.2562, Train Accuracy: 93.27%, Test Accuracy: 79.69%
# Epoch: 41, Loss: 0.2507, Train Accuracy: 93.27%, Test Accuracy: 79.69%
# Epoch: 42, Loss: 0.2470, Train Accuracy: 93.27%, Test Accuracy: 79.69%
# Epoch: 43, Loss: 0.2417, Train Accuracy: 93.27%, Test Accuracy: 79.69%
# Epoch: 44, Loss: 0.2382, Train Accuracy: 93.27%, Test Accuracy: 79.69%
# Epoch: 45, Loss: 0.2326, Train Accuracy: 93.27%, Test Accuracy: 79.69%
# Epoch: 46, Loss: 0.2291, Train Accuracy: 94.23%, Test Accuracy: 79.69%
# Epoch: 47, Loss: 0.2250, Train Accuracy: 94.23%, Test Accuracy: 79.69%
# Epoch: 48, Loss: 0.2212, Train Accuracy: 94.23%, Test Accuracy: 79.69%
# Epoch: 49, Loss: 0.2173, Train Accuracy: 94.23%, Test Accuracy: 79.69%
# Epoch: 50, Loss: 0.2137, Train Accuracy: 94.23%, Test Accuracy: 79.69%
# Epoch: 51, Loss: 0.2100, Train Accuracy: 94.23%, Test Accuracy: 80.47%
# Epoch: 52, Loss: 0.2064, Train Accuracy: 94.23%, Test Accuracy: 80.47%
# Epoch: 53, Loss: 0.2028, Train Accuracy: 94.23%, Test Accuracy: 80.47%
# Epoch: 54, Loss: 0.1995, Train Accuracy: 94.23%, Test Accuracy: 80.47%
# Epoch: 55, Loss: 0.1962, Train Accuracy: 95.19%, Test Accuracy: 80.47%
# Epoch: 56, Loss: 0.1927, Train Accuracy: 95.19%, Test Accuracy: 80.47%
# Epoch: 57, Loss: 0.1889, Train Accuracy: 95.19%, Test Accuracy: 80.47%
# Epoch: 58, Loss: 0.1851, Train Accuracy: 95.19%, Test Accuracy: 79.69%
# Epoch: 59, Loss: 0.1812, Train Accuracy: 95.19%, Test Accuracy: 80.47%
# Epoch: 60, Loss: 0.1778, Train Accuracy: 95.19%, Test Accuracy: 80.47%
# Epoch: 61, Loss: 0.1720, Train Accuracy: 96.15%, Test Accuracy: 80.47%
# Epoch: 62, Loss: 0.1641, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 63, Loss: 0.1603, Train Accuracy: 96.15%, Test Accuracy: 78.12%
# Epoch: 64, Loss: 0.1548, Train Accuracy: 96.15%, Test Accuracy: 78.12%
# Epoch: 65, Loss: 0.1511, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 66, Loss: 0.1481, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 67, Loss: 0.1449, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 68, Loss: 0.1417, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 69, Loss: 0.1388, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 70, Loss: 0.1361, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 71, Loss: 0.1334, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 72, Loss: 0.1308, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 73, Loss: 0.1283, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 74, Loss: 0.1259, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 75, Loss: 0.1236, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 76, Loss: 0.1213, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 77, Loss: 0.1190, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 78, Loss: 0.1168, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 79, Loss: 0.1147, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 80, Loss: 0.1126, Train Accuracy: 96.15%, Test Accuracy: 79.69%
# Epoch: 81, Loss: 0.1106, Train Accuracy: 97.12%, Test Accuracy: 78.91%
# Epoch: 82, Loss: 0.1087, Train Accuracy: 97.12%, Test Accuracy: 78.91%
# Epoch: 83, Loss: 0.1067, Train Accuracy: 97.12%, Test Accuracy: 78.91%
# Epoch: 84, Loss: 0.1047, Train Accuracy: 98.08%, Test Accuracy: 78.91%
# Epoch: 85, Loss: 0.1028, Train Accuracy: 98.08%, Test Accuracy: 78.91%
# Epoch: 86, Loss: 0.1009, Train Accuracy: 98.08%, Test Accuracy: 78.91%
# Epoch: 87, Loss: 0.0992, Train Accuracy: 98.08%, Test Accuracy: 78.91%
# Epoch: 88, Loss: 0.0975, Train Accuracy: 98.08%, Test Accuracy: 78.91%
# Epoch: 89, Loss: 0.0958, Train Accuracy: 98.08%, Test Accuracy: 78.91%
# Epoch: 90, Loss: 0.0942, Train Accuracy: 98.08%, Test Accuracy: 78.12%
# Epoch: 91, Loss: 0.0926, Train Accuracy: 98.08%, Test Accuracy: 78.91%
# Epoch: 92, Loss: 0.0910, Train Accuracy: 98.08%, Test Accuracy: 78.12%
# Epoch: 93, Loss: 0.0896, Train Accuracy: 98.08%, Test Accuracy: 78.12%
# Epoch: 94, Loss: 0.0881, Train Accuracy: 98.08%, Test Accuracy: 78.12%
# Epoch: 95, Loss: 0.0866, Train Accuracy: 98.08%, Test Accuracy: 78.12%
# Epoch: 96, Loss: 0.0853, Train Accuracy: 98.08%, Test Accuracy: 78.12%
# Epoch: 97, Loss: 0.0839, Train Accuracy: 98.08%, Test Accuracy: 77.34%
# Epoch: 98, Loss: 0.0825, Train Accuracy: 98.08%, Test Accuracy: 76.56%
# Epoch: 99, Loss: 0.0811, Train Accuracy: 98.08%, Test Accuracy: 76.56%
# Epoch: 100, Loss: 0.0799, Train Accuracy: 98.08%, Test Accuracy: 76.56%
# Final Test Accuracy: 76.56%

# %%
print(test_acc_list[33],test_acc_list[66],test_acc_list[99])
print(acc_list[33],acc_list[66],acc_list[99])
# Out:
# 78.125 79.6875 76.5625
# 92.3076923076923 96.15384615384616 98.07692307692307

# %%
print(f"test_acc_list: {[f'{val:.2f}' for val in test_acc_list]}")
print(f"acc_list: {[f'{val:.2f}' for val in acc_list]}")
# Out:
# test_acc_list: ['19.53', '40.62', '41.41', '46.88', '52.34', '57.81', '64.06', '68.75', '71.09', '74.22', '75.00', '75.78', '77.34', '76.56', '76.56', '76.56', '76.56', '77.34', '77.34', '77.34', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '77.34', '78.91', '78.12', '78.91', '78.91', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '80.47', '80.47', '80.47', '80.47', '80.47', '80.47', '80.47', '79.69', '80.47', '80.47', '80.47', '79.69', '78.12', '78.12', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '79.69', '78.91', '78.91', '78.91', '78.91', '78.91', '78.91', '78.91', '78.91', '78.91', '78.12', '78.91', '78.12', '78.12', '78.12', '78.12', '78.12', '77.34', '76.56', '76.56', '76.56']
# acc_list: ['25.00', '48.08', '49.04', '55.77', '56.73', '65.38', '70.19', '75.96', '78.85', '81.73', '82.69', '84.62', '84.62', '84.62', '85.58', '85.58', '85.58', '85.58', '87.50', '88.46', '88.46', '88.46', '90.38', '90.38', '91.35', '91.35', '91.35', '91.35', '91.35', '92.31', '91.35', '92.31', '92.31', '92.31', '91.35', '93.27', '93.27', '93.27', '93.27', '93.27', '93.27', '93.27', '93.27', '93.27', '93.27', '94.23', '94.23', '94.23', '94.23', '94.23', '94.23', '94.23', '94.23', '94.23', '95.19', '95.19', '95.19', '95.19', '95.19', '95.19', '96.15', '96.15', '96.15', '96.15', '96.15', '96.15', '96.15', '96.15', '96.15', '96.15', '96.15', '96.15', '96.15', '96.15', '96.15', '96.15', '96.15', '96.15', '96.15', '96.15', '97.12', '97.12', '97.12', '98.08', '98.08', '98.08', '98.08', '98.08', '98.08', '98.08', '98.08', '98.08', '98.08', '98.08', '98.08', '98.08', '98.08', '98.08', '98.08', '98.08']

# %%
# %%
def translate(array):
    arr = []
    for e in array:
        arr.append(torch.argmax(e))
    return arr
print(f"output 0: {translate(output0)}, \n Y:       {translate(Y)}, \n output 1: {translate(output1)}, \n Y1:       {translate(Y1)}")

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 6), subplot_kw={"xticks": [], "yticks": []})
for i in range(0, 4):
    ax[i // 2, i % 2].imshow(X1.detach().cpu().numpy()[i].reshape(4, 4), aspect="equal")
    if torch.argmax(output1[i]) == 0:
        ax[i // 2, i % 2].set_title("The CNN predicts this is 3")
    if torch.argmax(output1[i]) == 1:
        ax[i // 2, i % 2].set_title("The CNN predicts this is 4")
    if torch.argmax(output1[i]) == 2:
        ax[i // 2, i % 2].set_title("The CNN predicts this is 5")
    if torch.argmax(output1[i]) == 3:
        ax[i // 2, i % 2].set_title("The CNN predicts this is 6")
plt.subplots_adjust(wspace=0.1, hspace=0.5)

# %%
num_rows = 10
num_cols = 10
fig, ax = plt.subplots(num_rows, num_cols, figsize=(20, 20),
                       subplot_kw={"xticks": [], "yticks": []})

for i in range(num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    
    if i < len(x_test) and i < len(output1):
      ax[row, col].imshow(x_test[i].reshape(28, 28), aspect="equal")

      if torch.argmax(output1[i]) == 0:
          ax[row, col].set_title("CNN: 3")
      elif torch.argmax(output1[i]) == 1:
          ax[row, col].set_title("CNN: 4")
      elif torch.argmax(output1[i]) == 2:
          ax[row, col].set_title("CNN: 5")
      elif torch.argmax(output1[i]) == 3:
          ax[row, col].set_title("CNN: 6")
    else:
        ax[row, col].axis('off')

plt.subplots_adjust(wspace=0.1, hspace=0.5)
plt.show()
# Out:
# output 0: [tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0')],
#  Y:       [tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0')],
#  output 1: [tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0')],
#  Y1:       [tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0')]
