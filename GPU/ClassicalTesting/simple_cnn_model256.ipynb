# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.nn import Linear, Softmax, Sigmoid, Module
from scipy.optimize import minimize
from IPython.display import clear_output

# Creating/Formatting Data

import tensorflow as tf
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train[..., np.newaxis]/(255.0/np.pi), x_test[..., np.newaxis]/(255.0/np.pi)
print("Number of original training examples:", len(x_train))
print("Number of original test examples:", len(x_test))

# Filter Values
a = 3
b = 4
c = 5
d = 6
def filter_abcd(x, y):
    keep = (y == a) | (y == b) | (y == c) | (y == d)
    x, y = x[keep], y[keep]
    return x,y

# Filtering using previous method.
x_train, y_train = filter_abcd(x_train, y_train)
x_test, y_test = filter_abcd(x_test, y_test)

print("Number of filtered training examples:", len(x_train))
print("Number of filtered test examples:", len(x_test))

# Displaying Sample Image
img = 13
print(y_train[img])
plt.imshow(x_train[img, :, :, 0])
plt.colorbar()

# Resizing (Quantum Computing Simulation Limit)
x_train_small = tf.image.resize(x_train, (4,4), method = 'area').numpy()
x_test_small = tf.image.resize(x_test, (4,4), method = 'area').numpy()

# Displaying Image Sample After Resizing
img = 13
print(y_train[img])
plt.imshow(x_train_small[img,:,:,0], vmin=0, vmax=np.pi)
plt.colorbar()

# Formatting Helper Methods
def format_data(a,b):
    x_reshaped = []
    x1_reshaped = []

    for g in a:
        x_reshaped.append(g.reshape(1,16))

    for g in b:
        x1_reshaped.append(g.reshape(1,16))

    final_x = []
    final_x1 = []

    for entry in x_reshaped:
        final_x.append(entry[0])

    for entry in x1_reshaped:
        final_x1.append(entry[0])
    return final_x, final_x1

def format_labels(y):
    y_temp = []
    for entry in y:
        if entry == a:
            y_temp.append(0)
        elif entry == b:
            y_temp.append(1)
        elif entry == c:
            y_temp.append(2)
        elif entry == d:
            y_temp.append(3)
    return y_temp

x,x1 = format_data(x_train_small, x_test_small)

# Easier to work with names
y = y_train
y1 = y_test

# Setting labels to 0,1,2,3 for easy reference later
y = format_labels(y)
y1 = format_labels(y1)

# Converting to nparray
x = np.asarray(x)
y = np.asarray(y)
x1 = np.asarray(x1)
y1 = np.asarray(y1)

# Limiting training dataset to lower training time.
x = x[0:256]
y = y[0:256]
x1 = x1[0:256]
y1 = y1[0:256]
print(x)
print(y)

# Additional Helper Functions
def count(y):
    counta = 0
    countb = 0
    countc = 0
    countd = 0
    for i in range(len(y)):
        if y[i] == 0:
            counta+=1
        elif y[i] == 1:
            countb+=1
        elif y[i] == 2:
            countc+=1
        elif y[i] == 3:
            countd+=1
    return(counta, countb, countc, countd)

def balance_lists(x, y, max_count):
    """Balances two lists x and y based on the values in y (0 or 1)."""
    
    x_balanced = []
    y_balanced = []
    count0 = 0
    count1 = 0
    count2 = 0
    count3 = 0

    for i in range(len(y)):
        if y[i] == 0:
            if count0 < max_count:
                x_balanced.append(x[i])
                y_balanced.append(y[i])
                count0 += 1
        elif y[i] == 1:
            if count1 < max_count:
                x_balanced.append(x[i])
                y_balanced.append(y[i])
                count1 += 1
        elif y[i] == 2:
            if count2 < max_count:
                x_balanced.append(x[i])
                y_balanced.append(y[i])
                count2 += 1
        elif y[i] == 3:
            if count3 < max_count:
                x_balanced.append(x[i])
                y_balanced.append(y[i])
                count3 += 1
    return x_balanced, y_balanced

def shuffle(arr1, arr2):
    assert len(arr1) == len(arr2)
    p = np.random.permutation(len(arr1))
    return arr1[p], arr2[p]

# Further Data Cleaning Using Helper Functions
nums = count(y)
print("original:", nums)
max_count = min(nums)
print("max_count =", max_count)
x,y = balance_lists(x, y, max_count)

print("balanced:", count(y))

# Converting to nparray
x = np.asarray(x)
y = np.asarray(y)
x1 = np.asarray(x1)
y1 = np.asarray(y1)
objective_func_vals = []

x,y = shuffle(x,y)
print("shuffled:", count(y))

print("final:", x)
print(y)

# Tensor for Pytorch
X = torch.tensor(x, dtype=torch.float32).to("cuda").reshape(-1, 1, 4, 4)
Y = torch.tensor(y, dtype=torch.long).to("cuda")
X1 = torch.tensor(x1, dtype=torch.float32).to("cuda").reshape(-1, 1, 4, 4)
Y1 = torch.tensor(y1, dtype=torch.long).to("cuda")

# One-Hot Encoding for Final Processing
num_classes = 4
Y = (torch.nn.functional.one_hot(Y, num_classes=num_classes).float())
Y1 = (torch.nn.functional.one_hot(Y1, num_classes=num_classes).float())

print(X.shape,Y.shape,X1.shape,Y1.shape)

# Training

import torch
import torch.nn as nn
import torch.nn.functional as F

# Simplified CNN Model
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=4):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=4, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(4 * 2 * 2, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = x.view(-1, 4 * 2 * 2)
        x = self.fc1(x)
        return x

# Create an instance of the model
model = SimpleCNN().to("cuda")

# Loss Function and Optimizer
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# Accuracy Function
def accuracy(output, y):
    preds = torch.argmax(output, dim=1)
    true = torch.argmax(y, dim=1)
    correct = (preds == true).sum().item()
    return (correct / y.size(0)) * 100

# Training Loop
def train(model, X, Y, X1, Y1, optimizer, loss_function, epochs=100, batch_size=8):
    model.train()
    loss_list = []
    train_acc_list = []
    test_acc_list = []
    for epoch in range(epochs):
        for i in range(0, X.size(0), batch_size):
            X_batch = X[i:i + batch_size]
            Y_batch = Y[i:i + batch_size]

            # Forward pass
            output = model(X_batch)
            loss = loss_function(output, Y_batch)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # Calculate loss and accuracy for the entire epoch (optional, for monitoring)
        with torch.no_grad():
            #Train Data
            output = model(X)
            epoch_loss = loss_function(output, Y).item()
            epoch_train_acc = accuracy(output, Y)
            
            #Test Data
            test_output = model(X1)
            epoch_test_acc = accuracy(test_output, Y1)
            
            loss_list.append(epoch_loss)
            train_acc_list.append(epoch_train_acc)
            test_acc_list.append(epoch_test_acc)
            
            print(f"Epoch: {epoch+1}, Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_train_acc:.2f}%, Test Accuracy: {epoch_test_acc:.2f}%")
    return loss_list, train_acc_list, test_acc_list

# Train the Model
loss_list, acc_list, test_acc_list = train(model, X, Y, X1, Y1, optimizer, loss_function, epochs=95)

# Plot Loss and Accuracy
plt.figure(figsize=(15, 4))
plt.subplot(1, 3, 1)
plt.plot(loss_list)
plt.title("Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.subplot(1, 3, 2)
plt.plot(acc_list)
plt.title("Training Accuracy over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")

plt.subplot(1, 3, 3)
plt.plot(test_acc_list)
plt.title("Test Accuracy over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")


plt.tight_layout()
plt.show()

# Evaluate on Test Data
model.eval()
with torch.no_grad():
    output0 = model(X)
    output1 = model(X1)
    test_acc = accuracy(output1, Y1)
    print(f"Final Test Accuracy: {test_acc:.2f}%")

# Save the Model
torch.save(model.state_dict(), "simple_cnn_model256.pth")
# Out:
# 2025-01-22 15:24:27.116260: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737588267.130306   17581 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737588267.134345   17581 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-22 15:24:27.148344: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Number of original training examples: 60000
# Number of original test examples: 10000
# Number of filtered training examples: 23312
# Number of filtered test examples: 3842
# 6
# I0000 00:00:1737588269.275155   17581 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# 6
# [[0.         0.19058241 0.5850729  ... 1.2083628  0.15663964 0.        ]
#  [0.0359542  0.         0.04701703 ... 0.         0.54685587 0.        ]
#  [0.         0.26902792 0.86968946 ... 1.3765682  0.4684103  0.        ]
#  ...
#  [0.         0.3354049  0.         ... 0.40329048 0.46539322 0.        ]
#  [0.         0.0548113  0.8850265  ... 0.9554263  0.27833077 0.        ]
#  [0.         0.10283405 0.05279988 ... 0.35426205 0.24916515 0.        ]]
# [2 1 0 1 0 2 0 3 3 1 1 0 0 3 2 3 3 0 2 0 0 1 1 1 1 3 1 2 3 3 0 3 0 1 3 1 3
#  0 2 3 0 0 1 3 1 3 0 1 2 0 0 2 1 1 2 3 0 1 3 3 0 1 1 3 1 2 2 0 0 2 3 2 1 0
#  0 3 0 0 1 3 2 3 1 0 0 2 1 3 2 3 0 2 0 0 0 3 1 2 3 2 1 1 2 3 1 2 0 0 2 3 2
#  1 0 1 1 1 0 3 3 2 3 1 2 0 3 0 2 1 0 3 2 2 1 1 0 1 1 0 0 1 3 1 1 1 2 1 1 3
#  0 3 2 3 1 2 0 2 1 1 1 2 2 3 0 3 3 0 2 1 1 3 0 0 1 2 3 2 0 2 1 0 3 0 3 0 2
#  3 0 2 2 3 0 2 2 2 2 2 1 3 3 2 0 1 2 2 0 3 0 2 0 0 1 3 1 0 1 3 2 0 1 1 3 3
#  3 1 1 3 2 0 2 1 2 2 3 2 0 3 2 0 0 1 3 2 2 1 3 0 3 1 1 3 0 3 0 1 2 1]
# original: (66, 68, 60, 62)
# max_count = 60
# balanced: (60, 60, 60, 60)
# shuffled: (60, 60, 60, 60)
# final: [[0.0000000e+00 1.7197673e-01 8.2267237e-01 ... 1.2636770e+00
#   5.4861587e-01 0.0000000e+00]
#  [0.0000000e+00 2.7103937e-01 1.1791972e+00 ... 1.4607966e-01
#   6.8212414e-01 1.6845675e-02]
#  [0.0000000e+00 0.0000000e+00 2.1698233e-01 ... 9.5894629e-01
#   3.0422784e-02 0.0000000e+00]
#  ...
#  [0.0000000e+00 0.0000000e+00 9.8056914e-03 ... 5.3805590e-01
#   3.5199916e-03 0.0000000e+00]
#  [0.0000000e+00 1.0057118e-03 7.0098114e-01 ... 0.0000000e+00
#   1.0660547e-01 0.0000000e+00]
#  [0.0000000e+00 5.5314153e-03 6.8262696e-01 ... 9.9364346e-01
#   5.7375866e-01 0.0000000e+00]]
# [0 3 0 3 1 2 0 3 2 0 1 2 3 0 3 1 3 2 2 2 0 2 2 3 2 2 0 1 3 2 2 0 2 3 1 0 1
#  1 1 2 3 1 2 2 3 2 2 1 0 0 2 2 3 3 0 3 3 0 1 3 3 2 1 0 2 0 2 3 3 0 1 3 0 3
#  3 0 2 0 2 0 0 2 3 1 2 1 1 3 3 3 1 2 1 0 2 1 3 0 1 1 3 3 2 3 2 1 2 0 1 2 0
#  2 1 0 3 2 0 0 1 3 1 1 2 3 0 1 2 0 3 1 1 1 0 0 2 1 1 3 0 1 1 1 0 3 1 3 0 3
#  3 1 3 0 1 3 2 0 0 1 2 1 0 0 0 1 2 3 2 1 1 1 0 3 3 3 1 3 2 2 3 3 0 0 2 2 2
#  2 2 3 0 2 1 0 0 0 3 0 1 3 1 0 1 0 1 2 2 1 2 1 0 2 3 0 0 2 1 3 1 0 1 1 3 0
#  2 0 3 3 3 1 2 0 1 3 0 2 3 2 0 1 3 2]
# torch.Size([240, 1, 4, 4]) torch.Size([240, 4]) torch.Size([256, 1, 4, 4]) torch.Size([256, 4])
# Epoch: 1, Loss: 1.3335, Train Accuracy: 40.42%, Test Accuracy: 30.86%
# Epoch: 2, Loss: 1.1100, Train Accuracy: 62.50%, Test Accuracy: 57.03%
# Epoch: 3, Loss: 0.8936, Train Accuracy: 62.08%, Test Accuracy: 64.45%
# Epoch: 4, Loss: 0.7811, Train Accuracy: 67.50%, Test Accuracy: 66.02%
# Epoch: 5, Loss: 0.6992, Train Accuracy: 74.17%, Test Accuracy: 70.31%
# Epoch: 6, Loss: 0.6412, Train Accuracy: 75.42%, Test Accuracy: 71.88%
# Epoch: 7, Loss: 0.5996, Train Accuracy: 76.67%, Test Accuracy: 73.44%
# Epoch: 8, Loss: 0.5691, Train Accuracy: 76.67%, Test Accuracy: 73.05%
# Epoch: 9, Loss: 0.5458, Train Accuracy: 77.08%, Test Accuracy: 73.44%
# Epoch: 10, Loss: 0.5250, Train Accuracy: 78.33%, Test Accuracy: 73.05%
# Epoch: 11, Loss: 0.5051, Train Accuracy: 79.17%, Test Accuracy: 74.22%
# Epoch: 12, Loss: 0.4874, Train Accuracy: 80.42%, Test Accuracy: 74.22%
# Epoch: 13, Loss: 0.4712, Train Accuracy: 80.83%, Test Accuracy: 75.39%
# Epoch: 14, Loss: 0.4559, Train Accuracy: 80.83%, Test Accuracy: 76.56%
# Epoch: 15, Loss: 0.4413, Train Accuracy: 81.25%, Test Accuracy: 75.78%
# Epoch: 16, Loss: 0.4281, Train Accuracy: 82.50%, Test Accuracy: 76.56%
# Epoch: 17, Loss: 0.4155, Train Accuracy: 83.75%, Test Accuracy: 77.73%
# Epoch: 18, Loss: 0.4022, Train Accuracy: 84.58%, Test Accuracy: 77.34%
# Epoch: 19, Loss: 0.3930, Train Accuracy: 85.42%, Test Accuracy: 77.73%
# Epoch: 20, Loss: 0.3843, Train Accuracy: 85.00%, Test Accuracy: 77.34%
# Epoch: 21, Loss: 0.3743, Train Accuracy: 85.00%, Test Accuracy: 77.34%
# Epoch: 22, Loss: 0.3680, Train Accuracy: 85.42%, Test Accuracy: 77.34%
# Epoch: 23, Loss: 0.3586, Train Accuracy: 86.25%, Test Accuracy: 76.95%
# Epoch: 24, Loss: 0.3514, Train Accuracy: 86.67%, Test Accuracy: 77.34%
# Epoch: 25, Loss: 0.3441, Train Accuracy: 86.67%, Test Accuracy: 78.52%
# Epoch: 26, Loss: 0.3371, Train Accuracy: 87.08%, Test Accuracy: 78.91%
# Epoch: 27, Loss: 0.3313, Train Accuracy: 86.67%, Test Accuracy: 78.91%
# Epoch: 28, Loss: 0.3255, Train Accuracy: 86.67%, Test Accuracy: 78.91%
# Epoch: 29, Loss: 0.3205, Train Accuracy: 87.08%, Test Accuracy: 78.91%
# Epoch: 30, Loss: 0.3137, Train Accuracy: 87.50%, Test Accuracy: 78.91%
# Epoch: 31, Loss: 0.3066, Train Accuracy: 88.33%, Test Accuracy: 78.91%
# Epoch: 32, Loss: 0.3011, Train Accuracy: 87.92%, Test Accuracy: 78.91%
# Epoch: 33, Loss: 0.2976, Train Accuracy: 88.75%, Test Accuracy: 79.30%
# Epoch: 34, Loss: 0.2925, Train Accuracy: 88.75%, Test Accuracy: 79.30%
# Epoch: 35, Loss: 0.2885, Train Accuracy: 88.33%, Test Accuracy: 79.30%
# Epoch: 36, Loss: 0.2849, Train Accuracy: 89.17%, Test Accuracy: 79.30%
# Epoch: 37, Loss: 0.2811, Train Accuracy: 89.17%, Test Accuracy: 79.30%
# Epoch: 38, Loss: 0.2770, Train Accuracy: 89.58%, Test Accuracy: 78.91%
# Epoch: 39, Loss: 0.2729, Train Accuracy: 89.58%, Test Accuracy: 78.91%
# Epoch: 40, Loss: 0.2692, Train Accuracy: 89.58%, Test Accuracy: 79.30%
# Epoch: 41, Loss: 0.2685, Train Accuracy: 90.00%, Test Accuracy: 79.30%
# Epoch: 42, Loss: 0.2629, Train Accuracy: 90.00%, Test Accuracy: 79.30%
# Epoch: 43, Loss: 0.2604, Train Accuracy: 90.00%, Test Accuracy: 78.91%
# Epoch: 44, Loss: 0.2573, Train Accuracy: 90.42%, Test Accuracy: 78.91%
# Epoch: 45, Loss: 0.2532, Train Accuracy: 90.42%, Test Accuracy: 78.52%
# Epoch: 46, Loss: 0.2495, Train Accuracy: 90.42%, Test Accuracy: 78.52%
# Epoch: 47, Loss: 0.2459, Train Accuracy: 90.42%, Test Accuracy: 78.12%
# Epoch: 48, Loss: 0.2428, Train Accuracy: 91.67%, Test Accuracy: 78.12%
# Epoch: 49, Loss: 0.2398, Train Accuracy: 91.25%, Test Accuracy: 78.12%
# Epoch: 50, Loss: 0.2369, Train Accuracy: 91.67%, Test Accuracy: 78.52%
# Epoch: 51, Loss: 0.2337, Train Accuracy: 91.67%, Test Accuracy: 78.91%
# Epoch: 52, Loss: 0.2310, Train Accuracy: 92.08%, Test Accuracy: 78.91%
# Epoch: 53, Loss: 0.2284, Train Accuracy: 91.67%, Test Accuracy: 78.91%
# Epoch: 54, Loss: 0.2278, Train Accuracy: 91.67%, Test Accuracy: 78.91%
# Epoch: 55, Loss: 0.2248, Train Accuracy: 91.67%, Test Accuracy: 78.12%
# Epoch: 56, Loss: 0.2208, Train Accuracy: 92.08%, Test Accuracy: 78.12%
# Epoch: 57, Loss: 0.2200, Train Accuracy: 91.67%, Test Accuracy: 78.12%
# Epoch: 58, Loss: 0.2179, Train Accuracy: 92.08%, Test Accuracy: 78.12%
# Epoch: 59, Loss: 0.2154, Train Accuracy: 92.50%, Test Accuracy: 78.12%
# Epoch: 60, Loss: 0.2122, Train Accuracy: 92.50%, Test Accuracy: 78.12%
# Epoch: 61, Loss: 0.2100, Train Accuracy: 92.50%, Test Accuracy: 78.12%
# Epoch: 62, Loss: 0.2070, Train Accuracy: 91.67%, Test Accuracy: 78.12%
# Epoch: 63, Loss: 0.2042, Train Accuracy: 91.67%, Test Accuracy: 78.12%
# Epoch: 64, Loss: 0.2019, Train Accuracy: 92.08%, Test Accuracy: 78.12%
# Epoch: 65, Loss: 0.1998, Train Accuracy: 92.08%, Test Accuracy: 78.12%
# Epoch: 66, Loss: 0.1973, Train Accuracy: 92.50%, Test Accuracy: 78.12%
# Epoch: 67, Loss: 0.1946, Train Accuracy: 92.08%, Test Accuracy: 78.12%
# Epoch: 68, Loss: 0.1926, Train Accuracy: 92.08%, Test Accuracy: 78.52%
# Epoch: 69, Loss: 0.1908, Train Accuracy: 92.08%, Test Accuracy: 78.52%
# Epoch: 70, Loss: 0.1887, Train Accuracy: 92.50%, Test Accuracy: 78.52%
# Epoch: 71, Loss: 0.1871, Train Accuracy: 92.92%, Test Accuracy: 78.52%
# Epoch: 72, Loss: 0.1853, Train Accuracy: 92.92%, Test Accuracy: 78.91%
# Epoch: 73, Loss: 0.1837, Train Accuracy: 92.92%, Test Accuracy: 78.91%
# Epoch: 74, Loss: 0.1815, Train Accuracy: 93.33%, Test Accuracy: 78.91%
# Epoch: 75, Loss: 0.1812, Train Accuracy: 93.33%, Test Accuracy: 78.91%
# Epoch: 76, Loss: 0.1791, Train Accuracy: 93.75%, Test Accuracy: 78.91%
# Epoch: 77, Loss: 0.1777, Train Accuracy: 93.33%, Test Accuracy: 78.91%
# Epoch: 78, Loss: 0.1759, Train Accuracy: 93.75%, Test Accuracy: 78.91%
# Epoch: 79, Loss: 0.1751, Train Accuracy: 94.17%, Test Accuracy: 78.91%
# Epoch: 80, Loss: 0.1726, Train Accuracy: 93.75%, Test Accuracy: 78.52%
# Epoch: 81, Loss: 0.1712, Train Accuracy: 94.17%, Test Accuracy: 78.52%
# Epoch: 82, Loss: 0.1697, Train Accuracy: 94.17%, Test Accuracy: 78.52%
# Epoch: 83, Loss: 0.1678, Train Accuracy: 94.17%, Test Accuracy: 78.52%
# Epoch: 84, Loss: 0.1661, Train Accuracy: 94.17%, Test Accuracy: 78.52%
# Epoch: 85, Loss: 0.1633, Train Accuracy: 94.17%, Test Accuracy: 78.91%
# Epoch: 86, Loss: 0.1624, Train Accuracy: 94.58%, Test Accuracy: 78.52%
# Epoch: 87, Loss: 0.1612, Train Accuracy: 94.17%, Test Accuracy: 78.52%
# Epoch: 88, Loss: 0.1594, Train Accuracy: 94.17%, Test Accuracy: 78.52%
# Epoch: 89, Loss: 0.1570, Train Accuracy: 94.17%, Test Accuracy: 78.12%
# Epoch: 90, Loss: 0.1554, Train Accuracy: 94.17%, Test Accuracy: 78.12%
# Epoch: 91, Loss: 0.1538, Train Accuracy: 94.17%, Test Accuracy: 78.12%
# Epoch: 92, Loss: 0.1511, Train Accuracy: 93.75%, Test Accuracy: 78.52%
# Epoch: 93, Loss: 0.1476, Train Accuracy: 94.17%, Test Accuracy: 78.12%
# Epoch: 94, Loss: 0.1449, Train Accuracy: 95.00%, Test Accuracy: 78.12%
# Epoch: 95, Loss: 0.1430, Train Accuracy: 95.00%, Test Accuracy: 78.12%
# Final Test Accuracy: 78.12%

# %%
print(test_acc_list[31],test_acc_list[62],test_acc_list[94])
print(acc_list[31],acc_list[62],acc_list[94])
# Out:
# 78.90625 78.125 78.125
# 87.91666666666667 91.66666666666666 95.0

# %%
print(f"test_acc_list: {[f'{val:.2f}' for val in test_acc_list]}")
print(f"acc_list: {[f'{val:.2f}' for val in acc_list]}")
# Out:
# test_acc_list: ['30.86', '57.03', '64.45', '66.02', '70.31', '71.88', '73.44', '73.05', '73.44', '73.05', '74.22', '74.22', '75.39', '76.56', '75.78', '76.56', '77.73', '77.34', '77.73', '77.34', '77.34', '77.34', '76.95', '77.34', '78.52', '78.91', '78.91', '78.91', '78.91', '78.91', '78.91', '78.91', '79.30', '79.30', '79.30', '79.30', '79.30', '78.91', '78.91', '79.30', '79.30', '79.30', '78.91', '78.91', '78.52', '78.52', '78.12', '78.12', '78.12', '78.52', '78.91', '78.91', '78.91', '78.91', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.12', '78.52', '78.52', '78.52', '78.52', '78.91', '78.91', '78.91', '78.91', '78.91', '78.91', '78.91', '78.91', '78.52', '78.52', '78.52', '78.52', '78.52', '78.91', '78.52', '78.52', '78.52', '78.12', '78.12', '78.12', '78.52', '78.12', '78.12', '78.12']
# acc_list: ['40.42', '62.50', '62.08', '67.50', '74.17', '75.42', '76.67', '76.67', '77.08', '78.33', '79.17', '80.42', '80.83', '80.83', '81.25', '82.50', '83.75', '84.58', '85.42', '85.00', '85.00', '85.42', '86.25', '86.67', '86.67', '87.08', '86.67', '86.67', '87.08', '87.50', '88.33', '87.92', '88.75', '88.75', '88.33', '89.17', '89.17', '89.58', '89.58', '89.58', '90.00', '90.00', '90.00', '90.42', '90.42', '90.42', '90.42', '91.67', '91.25', '91.67', '91.67', '92.08', '91.67', '91.67', '91.67', '92.08', '91.67', '92.08', '92.50', '92.50', '92.50', '91.67', '91.67', '92.08', '92.08', '92.50', '92.08', '92.08', '92.08', '92.50', '92.92', '92.92', '92.92', '93.33', '93.33', '93.75', '93.33', '93.75', '94.17', '93.75', '94.17', '94.17', '94.17', '94.17', '94.17', '94.58', '94.17', '94.17', '94.17', '94.17', '94.17', '93.75', '94.17', '95.00', '95.00']

# %%
# %%
def translate(array):
    arr = []
    for e in array:
        arr.append(torch.argmax(e))
    return arr
print(f"output 0: {translate(output0)}, \n Y:       {translate(Y)}, \n output 1: {translate(output1)}, \n Y1:       {translate(Y1)}")

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 6), subplot_kw={"xticks": [], "yticks": []})
for i in range(0, 4):
    ax[i // 2, i % 2].imshow(X1.detach().cpu().numpy()[i].reshape(4, 4), aspect="equal")
    if torch.argmax(output1[i]) == 0:
        ax[i // 2, i % 2].set_title("The CNN predicts this is 3")
    if torch.argmax(output1[i]) == 1:
        ax[i // 2, i % 2].set_title("The CNN predicts this is 4")
    if torch.argmax(output1[i]) == 2:
        ax[i // 2, i % 2].set_title("The CNN predicts this is 5")
    if torch.argmax(output1[i]) == 3:
        ax[i // 2, i % 2].set_title("The CNN predicts this is 6")
plt.subplots_adjust(wspace=0.1, hspace=0.5)

# %%
num_rows = 10
num_cols = 10
fig, ax = plt.subplots(num_rows, num_cols, figsize=(20, 20),
                       subplot_kw={"xticks": [], "yticks": []})

for i in range(num_rows * num_cols):
    row = i // num_cols
    col = i % num_cols
    
    if i < len(x_test) and i < len(output1):
      ax[row, col].imshow(x_test[i].reshape(28, 28), aspect="equal")

      if torch.argmax(output1[i]) == 0:
          ax[row, col].set_title("CNN: 3")
      elif torch.argmax(output1[i]) == 1:
          ax[row, col].set_title("CNN: 4")
      elif torch.argmax(output1[i]) == 2:
          ax[row, col].set_title("CNN: 5")
      elif torch.argmax(output1[i]) == 3:
          ax[row, col].set_title("CNN: 6")
    else:
        ax[row, col].axis('off')

plt.subplots_adjust(wspace=0.1, hspace=0.5)
plt.show()
# Out:
# output 0: [tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, dev ...
#  Y:       [tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, dev ...
#  output 1: [tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, de ...
#  Y1:       [tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(1, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(1, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(0, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(0, device='cuda:0'), tensor(2, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(1, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, device='cuda:0'), tensor(3, device='cuda:0'), tensor(2, de ...
